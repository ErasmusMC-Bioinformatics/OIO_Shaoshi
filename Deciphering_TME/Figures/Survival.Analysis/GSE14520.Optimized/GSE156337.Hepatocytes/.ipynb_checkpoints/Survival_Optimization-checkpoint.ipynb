# %%
import pandas as pd
import numpy as np
from sksurv.nonparametric import kaplan_meier_estimator as kmf
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test
import matplotlib.patches as mpatches

# %%
selected_cell = 'Hepatocytes'

# %%
estimation = pd.read_csv('GSE14520.Non-immune.csv',index_col=0)
estimation.head()
# Out:
#            Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# Mixture
# GSM362947             0.0     0.857934     0.040412           0.065746
# GSM362948             0.0     0.774579     0.082644           0.048744
# GSM362949             0.0     0.679952     0.078860           0.058294
# GSM362950             0.0     0.701245     0.103513           0.040908
# GSM362951             0.0     0.891538     0.040139           0.043650
#
#            Bi-Potent Cells  P-value  Correlation      RMSE
# Mixture
# GSM362947         0.035908        0     0.292077  1.462487
# GSM362948         0.094033        0     0.705280  0.905997
# GSM362949         0.182895        0     0.662427  0.882807
# GSM362950         0.154334        0     0.740078  0.792355
# GSM362951         0.024673        0     0.871067  0.761878

# %%
survival_data = pd.read_csv('GSE14520.Survival.csv',index_col=0)
survival_data.head()
# Out:
#            OS_E    OS  DFS_E   DFS
# GSM
# GSM363205     0  58.0      0  58.0
# GSM363115     0  66.6      0  66.6
# GSM362970     0  67.3      0  67.3
# GSM363354     1  10.4      1  10.4
# GSM363039     0  52.8      0  52.8

# %%
dfs_data = survival_data.filter(['DFS_E', 'DFS'])
dfs_data = dfs_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
dfs_data['DFS_E'] = [binary[event] for event in dfs_data['DFS_E']]
dfs_data['DFS_T'] = [time for time in dfs_data['DFS']]
dfs_data.head()
# Out:
#            DFS_E   DFS  DFS_T
# GSM
# GSM363205  False  58.0   58.0
# GSM363115  False  66.6   66.6
# GSM362970  False  67.3   67.3
# GSM363354   True  10.4   10.4
# GSM363039  False  52.8   52.8

# %%
survival_test = estimation.merge(dfs_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#            Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# GSM362947             0.0     0.857934     0.040412           0.065746
# GSM362948             0.0     0.774579     0.082644           0.048744
# GSM362949             0.0     0.679952     0.078860           0.058294
# GSM362950             0.0     0.701245     0.103513           0.040908
# GSM362952             0.0     0.896763     0.015916           0.063131
#
#            Bi-Potent Cells  P-value  Correlation      RMSE  DFS_E   DFS  DFS_T
# GSM362947         0.035908        0     0.292077  1.462487   True  50.0   50.0
# GSM362948         0.094033        0     0.705280  0.905997   True   8.8    8.8
# GSM362949         0.182895        0     0.662427  0.882807   True  18.2   18.2
# GSM362950         0.154334        0     0.740078  0.792355   True  30.1   30.1
# GSM362952         0.024190        0     0.918001  0.674010  False  54.3   54.3

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder.head()
# Out:
#            Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# GSM363269        0.000000     0.952887     0.016696           0.023752
# GSM362977        0.000000     0.952560     0.017077           0.019508
# GSM363148        0.000000     0.952382     0.007847           0.030389
# GSM363123        0.000000     0.951730     0.012156           0.017027
# GSM363035        0.004788     0.949694     0.004662           0.040857
#
#            Bi-Potent Cells  P-value  Correlation      RMSE  DFS_E   DFS  DFS_T
# GSM363269         0.006665        0     0.728458  1.071180   True  12.4   12.4
# GSM362977         0.010856        0     0.917012  0.750326  False  66.3   66.3
# GSM363148         0.009382        0     0.890409  0.803202   True  11.8   11.8
# GSM363123         0.019087        0     0.877638  0.827299  False  42.7   42.7
# GSM363035         0.000000        0     0.930155  0.717989   True  24.6   24.6

# %%
running_length = len(survival_reorder)

logrank_tests = []
cut_points = []

for i in range(running_length):
    cut_point = int(i+1)
    E = list(survival_reorder['DFS_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['DFS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
optimization
# Out:
# 76

# %%
dfs_cut_level = survival_reorder[selected_cell][optimization]
dfs_cut_level
# Out:
# 0.886306472709917

# %%
E = list(survival_reorder['DFS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['DFS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 0.00057

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#e6005c')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,73,24),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#e6005c',label='High Level of Hepatocytes (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of Hepatocytes (n = %s)'%len(E_low))
plt.text(40,0.75, 'Log Rank Test',fontsize=15)
plt.text(42,0.7, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=8)
plt.title('Disease-free Survival (GSE14520)',fontsize=16)
plt.savefig('GSE14520.%s.DFS.pdf'%selected_cell,format='pdf')

# %%
os_data = survival_data.filter(['OS_E', 'OS'])
os_data = os_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
os_data['OS_E'] = [binary[event] for event in os_data['OS_E']]
os_data['OS_T'] = [time for time in os_data['OS']]
os_data.head()
# Out:
#             OS_E    OS  OS_T
# GSM
# GSM363205  False  58.0  58.0
# GSM363115  False  66.6  66.6
# GSM362970  False  67.3  67.3
# GSM363354   True  10.4  10.4
# GSM363039  False  52.8  52.8

# %%
survival_test = estimation.merge(os_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#            Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# GSM362947             0.0     0.857934     0.040412           0.065746
# GSM362948             0.0     0.774579     0.082644           0.048744
# GSM362949             0.0     0.679952     0.078860           0.058294
# GSM362950             0.0     0.701245     0.103513           0.040908
# GSM362952             0.0     0.896763     0.015916           0.063131
#
#            Bi-Potent Cells  P-value  Correlation      RMSE   OS_E    OS  OS_T
# GSM362947         0.035908        0     0.292077  1.462487   True  59.2  59.2
# GSM362948         0.094033        0     0.705280  0.905997  False  61.4  61.4
# GSM362949         0.182895        0     0.662427  0.882807   True  18.2  18.2
# GSM362950         0.154334        0     0.740078  0.792355  False  57.5  57.5
# GSM362952         0.024190        0     0.918001  0.674010  False  54.3  54.3

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#            Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# GSM363269        0.000000     0.952887     0.016696           0.023752
# GSM362977        0.000000     0.952560     0.017077           0.019508
# GSM363148        0.000000     0.952382     0.007847           0.030389
# GSM363123        0.000000     0.951730     0.012156           0.017027
# GSM363035        0.004788     0.949694     0.004662           0.040857
# ...                   ...          ...          ...                ...
# GSM363055        0.000000     0.323901     0.368447           0.101022
# GSM363428        0.000000     0.278028     0.334091           0.087206
# GSM363393        0.000000     0.202565     0.548697           0.248738
# GSM363054        0.203565     0.119961     0.416918           0.124181
# GSM363184        0.356981     0.000000     0.264403           0.014397
#
#            Bi-Potent Cells  P-value  Correlation      RMSE   OS_E    OS  OS_T
# GSM363269         0.006665        0     0.728458  1.071180   True  52.7  52.7
# GSM362977         0.010856        0     0.917012  0.750326  False  66.3  66.3
# GSM363148         0.009382        0     0.890409  0.803202  False  52.4  52.4
# GSM363123         0.019087        0     0.877638  0.827299  False  42.7  42.7
# GSM363035         0.000000        0     0.930155  0.717989  False  56.1  56.1
# ...                    ...      ...          ...       ...    ...   ...   ...
# GSM363055         0.206630        0     0.259914  1.027828  False   7.3   7.3
# GSM363428         0.300674        0     0.022342  1.137977   True   3.8   3.8
# GSM363393         0.000000        0     0.232372  1.026100   True   4.0   4.0
# GSM363054         0.135375        0     0.032486  1.066361  False  53.8  53.8
# GSM363184         0.364220        0     0.093688  1.042946  False  16.3  16.3
#
# [242 rows x 11 columns]

# %%
running_length = len(survival_reorder)

logrank_tests = []
cut_points = []

for i in range(running_length):
    cut_point = int(i+1)
    E = list(survival_reorder['OS_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['OS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
#optimization = int(len(E)/2)

# %%
os_cut_level = survival_reorder[selected_cell][optimization]
os_cut_level
# Out:
# 0.858758805210702

# %%
E = list(survival_reorder['OS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['OS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 0.00324

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#3333cc')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,73,24),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#3333cc',label='High Level of Hepatocytes (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of Hepatocytes (n = %s)'%len(E_low))
plt.text(30,0.35, 'Log Rank Test',fontsize=15)
plt.text(32,0.3, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=8)
plt.title('Overall Survival (GSE14520)',fontsize=16)
plt.savefig('GSE14520.%s.OS.pdf'%selected_cell,format='pdf')

# %%
estimation = estimation.sort_values(selected_cell,ascending=False)
x = []
y = []
for key,value in enumerate(estimation[selected_cell]):
    x.append(key)
    y.append(value)

# %%
plt.figure(figsize=(6,6))
plt.scatter(x,y,color='orange')
plt.axhline(y=os_cut_level, xmin=0, xmax=100,color='#3333cc')
plt.axhline(y=dfs_cut_level, xmin=0, xmax=100,color='#e6005c')
plt.ylabel('Estimated Cell Fraction',fontsize=15)
plt.title('Cutting Point - %s'%selected_cell,fontsize=15)
dfs_patch = mpatches.Patch(color='#e6005c',label='DFS Cutting Level')
os_patch = mpatches.Patch(color='#3333cc',label='OS Cutting Level')
plt.legend(handles=[dfs_patch,os_patch],fontsize=12)
plt.savefig('Cutting_Point.%s'%selected_cell,format='pdf')
