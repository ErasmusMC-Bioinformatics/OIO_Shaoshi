# %%
import pandas as pd
import numpy as np
from sksurv.nonparametric import kaplan_meier_estimator as kmf
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test
import matplotlib.patches as mpatches

# %%
selected_cell = 'CAFs'

# %%
estimation = pd.read_csv('TCGA-LIHC.Mesenchyme.csv',index_col=0)
estimation.head()
# Out:
#                     Other  Hepatocytes  Proliferation      vSMC  \
# Mixture
# TCGA-FV-A495-01  0.443809     0.261241       0.083257  0.016736
# TCGA-G3-A3CH-11  0.305872     0.525305       0.017091  0.026283
# TCGA-CC-A3MB-01  0.540845     0.180801       0.060513  0.000000
# TCGA-BC-A3KF-01  0.648937     0.242699       0.000000  0.016786
# TCGA-DD-A4NV-01  0.346874     0.353283       0.000000  0.056060
#
#                  Stellate cells      CAFs  Pericytes  P-value  Correlation  \
# Mixture
# TCGA-FV-A495-01        0.040656  0.147452   0.006849        0     0.956110
# TCGA-G3-A3CH-11        0.069102  0.006428   0.049920        0     0.972299
# TCGA-CC-A3MB-01        0.097361  0.000000   0.120480        0     0.940356
# TCGA-BC-A3KF-01        0.000000  0.032126   0.059452        0     0.948020
# TCGA-DD-A4NV-01        0.064966  0.122436   0.056381        0     0.925465
#
#                      RMSE
# Mixture
# TCGA-FV-A495-01  0.378415
# TCGA-G3-A3CH-11  0.490151
# TCGA-CC-A3MB-01  0.542547
# TCGA-BC-A3KF-01  0.413964
# TCGA-DD-A4NV-01  0.382281

# %%
sample_list = [sample for sample in estimation.index.values if '-01' in sample]
estimation = estimation.reindex(sample_list)

# %%
survival_data = pd.read_csv('survival_LIHC_survival.txt',index_col=0,delimiter='\t')
sample_list = [sample for sample in survival_data.index.values if '-01' in sample]
survival_data = survival_data.reindex(sample_list)
survival_data.head()
# Out:
#                      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  DFI.time  PFI  \
# sample
# TCGA-2V-A95S-01  TCGA-2V-A95S   0      NaN  0.0       NaN  0.0       NaN    0
# TCGA-2Y-A9GS-01  TCGA-2Y-A9GS   1    724.0  1.0     724.0  1.0     102.0    1
# TCGA-2Y-A9GT-01  TCGA-2Y-A9GT   1   1624.0  1.0    1624.0  1.0    1083.0    1
# TCGA-2Y-A9GU-01  TCGA-2Y-A9GU   0   1939.0  0.0    1939.0  0.0    1939.0    0
# TCGA-2Y-A9GV-01  TCGA-2Y-A9GV   1   2532.0  1.0    2532.0  0.0    2532.0    1
#
#                  PFI.time Redaction
# sample
# TCGA-2V-A95S-01       NaN       NaN
# TCGA-2Y-A9GS-01     102.0       NaN
# TCGA-2Y-A9GT-01    1083.0       NaN
# TCGA-2Y-A9GU-01    1939.0       NaN
# TCGA-2Y-A9GV-01    1745.0       NaN

# %%
dfs_data = survival_data.filter(['DFI.time', 'DFI'])
dfs_data = dfs_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
dfs_data['DFS_E'] = [binary[event] for event in dfs_data['DFI']]
dfs_data['DFS_T'] = [time/30 for time in dfs_data['DFI.time']]
dfs_data.head()
# Out:
#                  DFI.time  DFI  DFS_E      DFS_T
# sample
# TCGA-2Y-A9GS-01     102.0  1.0   True   3.400000
# TCGA-2Y-A9GT-01    1083.0  1.0   True  36.100000
# TCGA-2Y-A9GU-01    1939.0  0.0  False  64.633333
# TCGA-2Y-A9GV-01    2532.0  0.0  False  84.400000
# TCGA-2Y-A9GW-01    1229.0  1.0   True  40.966667

# %%
survival_test = estimation.merge(dfs_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#
# TCGA-DD-AADQ-01        0.041165  0.000000   0.041481        0     0.424276
# TCGA-DD-AAVS-01        0.077518  0.000000   0.088076        0     0.849224
#
#                      RMSE  DFI.time  DFI  DFS_E      DFS_T
# TCGA-CC-A3MA-01  0.912079     261.0  1.0   True   8.700000
# TCGA-CC-A7IJ-01  0.933324     382.0  0.0  False  12.733333
# TCGA-ED-A97K-01  0.850914       6.0  0.0  False   0.200000
# TCGA-ED-A82E-01  0.985895     408.0  0.0  False  13.600000
# TCGA-DD-A4NS-01  0.579050     893.0  1.0   True  29.766667
# ...                   ...       ...  ...    ...        ...
# TCGA-ED-A7PY-01  0.712496     390.0  0.0  False  13.000000
# TCGA-CC-A9FS-01  0.408803     211.0  0.0  False   7.033333
# TCGA-DD-AAE9-01  0.668317     722.0  0.0  False  24.066667
# TCGA-DD-AADQ-01  0.907752     436.0  0.0  False  14.533333
# TCGA-DD-AAVS-01  0.689591    1823.0  0.0  False  60.766667
#
# [316 rows x 14 columns]

# %%
E = list(survival_reorder['DFS_E'])
mid_point = int(len(E)/2)
E_high = E[:mid_point]
E_low = E[mid_point:]
S = list(survival_reorder['DFS_T'])
S_high = S[:mid_point]
S_low = S[mid_point:]

# %%
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,4)
p
# Out:
# 0.3152

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#e6005c')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#e6005c',label='High Level of CAFs (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of CAFs (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Disease-free Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.DFS.pdf'%selected_cell,format='pdf')

# %%
os_data = survival_data.filter(['OS.time', 'OS'])
os_data = os_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
os_data['OS_E'] = [binary[event] for event in os_data['OS']]
os_data['OS_T'] = [time/30 for time in os_data['OS.time']]
os_data.head()
# Out:
#                  OS.time  OS   OS_E       OS_T
# sample
# TCGA-2Y-A9GS-01    724.0   1   True  24.133333
# TCGA-2Y-A9GT-01   1624.0   1   True  54.133333
# TCGA-2Y-A9GU-01   1939.0   0  False  64.633333
# TCGA-2Y-A9GV-01   2532.0   1   True  84.400000
# TCGA-2Y-A9GW-01   1271.0   1   True  42.366667

# %%
survival_test = estimation.merge(os_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                     Other  Hepatocytes  Proliferation      vSMC  \
# TCGA-FV-A495-01  0.443809     0.261241       0.083257  0.016736
# TCGA-CC-A3MB-01  0.540845     0.180801       0.060513  0.000000
# TCGA-BC-A3KF-01  0.648937     0.242699       0.000000  0.016786
# TCGA-DD-A4NV-01  0.346874     0.353283       0.000000  0.056060
# TCGA-CC-A1HT-01  0.602426     0.000000       0.127597  0.014010
#
#                  Stellate cells      CAFs  Pericytes  P-value  Correlation  \
# TCGA-FV-A495-01        0.040656  0.147452   0.006849        0     0.956110
# TCGA-CC-A3MB-01        0.097361  0.000000   0.120480        0     0.940356
# TCGA-BC-A3KF-01        0.000000  0.032126   0.059452        0     0.948020
# TCGA-DD-A4NV-01        0.064966  0.122436   0.056381        0     0.925465
# TCGA-CC-A1HT-01        0.029641  0.192867   0.033458        0     0.701488
#
#                      RMSE  OS.time  OS   OS_E       OS_T
# TCGA-FV-A495-01  0.378415      1.0   0  False   0.033333
# TCGA-CC-A3MB-01  0.542547    315.0   1   True  10.500000
# TCGA-BC-A3KF-01  0.413964      8.0   0  False   0.266667
# TCGA-DD-A4NV-01  0.382281   2398.0   0  False  79.933333
# TCGA-CC-A1HT-01  0.921574    101.0   1   True   3.366667

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#                     Other  Hepatocytes  Proliferation      vSMC  \
# TCGA-CC-A3MA-01  0.266766     0.030257       0.093116  0.012987
# TCGA-CC-A7IJ-01  0.417865     0.000000       0.148774  0.004331
# TCGA-CC-5260-01  0.424104     0.000000       0.077576  0.013854
# TCGA-ED-A97K-01  0.440422     0.070575       0.006953  0.031907
# TCGA-ED-A82E-01  0.435781     0.000000       0.043389  0.019493
# ...                   ...          ...            ...       ...
# TCGA-CC-A9FS-01  0.536155     0.260086       0.003282  0.000000
# TCGA-G3-A5SL-01  0.453889     0.352289       0.019664  0.074266
# TCGA-DD-AAE9-01  0.704905     0.158984       0.048280  0.003375
# TCGA-DD-AACP-01  0.669359     0.082052       0.119874  0.009187
# TCGA-DD-AAVS-01  0.671682     0.132618       0.020765  0.009341
#
#                  Stellate cells      CAFs  Pericytes  P-value  Correlation  \
# TCGA-CC-A3MA-01        0.000000  0.398387   0.198487        0     0.696050
# TCGA-CC-A7IJ-01        0.017493  0.370876   0.040660        0     0.680566
# TCGA-CC-5260-01        0.000000  0.359142   0.125324        0     0.462194
# TCGA-ED-A97K-01        0.030520  0.356060   0.063563        0     0.709718
# TCGA-ED-A82E-01        0.007240  0.338758   0.155338        0     0.191678
# ...                         ...       ...        ...      ...          ...
# TCGA-CC-A9FS-01        0.129678  0.000000   0.070799        0     0.938597
# TCGA-G3-A5SL-01        0.017196  0.000000   0.082697        0     0.953476
# TCGA-DD-AAE9-01        0.020225  0.000000   0.064231        0     0.819234
# TCGA-DD-AACP-01        0.043258  0.000000   0.076270        0     0.629989
# TCGA-DD-AAVS-01        0.077518  0.000000   0.088076        0     0.849224
#
#                      RMSE  OS.time  OS   OS_E       OS_T
# TCGA-CC-A3MA-01  0.912079    303.0   1   True  10.100000
# TCGA-CC-A7IJ-01  0.933324    382.0   0  False  12.733333
# TCGA-CC-5260-01  0.957387     87.0   1   True   2.900000
# TCGA-ED-A97K-01  0.850914      6.0   0  False   0.200000
# TCGA-ED-A82E-01  0.985895    408.0   0  False  13.600000
# ...                   ...      ...  ..    ...        ...
# TCGA-CC-A9FS-01  0.408803    211.0   0  False   7.033333
# TCGA-G3-A5SL-01  0.304934    621.0   0  False  20.700000
# TCGA-DD-AAE9-01  0.668317    722.0   0  False  24.066667
# TCGA-DD-AACP-01  0.850129    415.0   0  False  13.833333
# TCGA-DD-AAVS-01  0.689591   1823.0   0  False  60.766667
#
# [370 rows x 14 columns]

# %%
E = list(survival_reorder['OS_E'])
mid_point = int(len(E)/2)
E_high = E[:mid_point]
E_low = E[mid_point:]

# %%
S = list(survival_reorder['OS_T'])
S_high = S[:mid_point]
S_low = S[mid_point:]

# %%
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,4)
p
# Out:
# 0.3118

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#3333cc')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#3333cc',label='High Level of CAFs (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of CAFs (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Overall Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.OS.pdf'%selected_cell,format='pdf')
