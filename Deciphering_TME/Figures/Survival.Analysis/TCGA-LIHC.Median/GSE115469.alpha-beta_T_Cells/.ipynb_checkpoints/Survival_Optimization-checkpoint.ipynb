# %%
import pandas as pd
import numpy as np
from sksurv.nonparametric import kaplan_meier_estimator as kmf
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test
import matplotlib.patches as mpatches

# %%
selected_cell = 'alpha-beta_T_Cells'

# %%
estimation = pd.read_csv('Immune.Separate.csv',index_col=0)
estimation.head()
# Out:
#                     Other  Non-inflammatory_Macrophage  alpha-beta_T_Cells  \
# Mixture
# TCGA-FV-A495-01  0.516484                     0.041491            0.065599
# TCGA-G3-A3CH-11  0.728694                     0.027576            0.040000
# TCGA-CC-A3MB-01  0.436028                     0.037025            0.109933
# TCGA-BC-A3KF-01  0.550941                     0.081541            0.037102
# TCGA-DD-A4NV-01  0.627984                     0.009330            0.153352
#
#                  Inflammatory_Macrophage  NK-like_Cells  gamma-delta_T_Cells  \
# Mixture
# TCGA-FV-A495-01                 0.109361       0.044938             0.119505
# TCGA-G3-A3CH-11                 0.028437       0.056394             0.063245
# TCGA-CC-A3MB-01                 0.079121       0.103977             0.086439
# TCGA-BC-A3KF-01                 0.052791       0.111224             0.093377
# TCGA-DD-A4NV-01                 0.018680       0.055977             0.034729
#
#                  Mature_B_Cells  Plasma_Cells  P-value  Correlation      RMSE
# Mixture
# TCGA-FV-A495-01        0.020518      0.082104        0     0.850468  0.563478
# TCGA-G3-A3CH-11        0.055654      0.000000        0     0.902564  0.455653
# TCGA-CC-A3MB-01        0.023214      0.124263        0     0.758718  0.679785
# TCGA-BC-A3KF-01        0.019420      0.053604        0     0.798685  0.615268
# TCGA-DD-A4NV-01        0.034951      0.064996        0     0.730421  0.691170

# %%
sample_list = [sample for sample in estimation.index.values if '-01' in sample]
estimation = estimation.reindex(sample_list)

# %%
survival_data = pd.read_csv('survival_LIHC_survival.txt',index_col=0,delimiter='\t')
sample_list = [sample for sample in survival_data.index.values if '-01' in sample]
survival_data = survival_data.reindex(sample_list)
survival_data.head()
# Out:
#                      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  DFI.time  PFI  \
# sample
# TCGA-2V-A95S-01  TCGA-2V-A95S   0      NaN  0.0       NaN  0.0       NaN    0
# TCGA-2Y-A9GS-01  TCGA-2Y-A9GS   1    724.0  1.0     724.0  1.0     102.0    1
# TCGA-2Y-A9GT-01  TCGA-2Y-A9GT   1   1624.0  1.0    1624.0  1.0    1083.0    1
# TCGA-2Y-A9GU-01  TCGA-2Y-A9GU   0   1939.0  0.0    1939.0  0.0    1939.0    0
# TCGA-2Y-A9GV-01  TCGA-2Y-A9GV   1   2532.0  1.0    2532.0  0.0    2532.0    1
#
#                  PFI.time Redaction
# sample
# TCGA-2V-A95S-01       NaN       NaN
# TCGA-2Y-A9GS-01     102.0       NaN
# TCGA-2Y-A9GT-01    1083.0       NaN
# TCGA-2Y-A9GU-01    1939.0       NaN
# TCGA-2Y-A9GV-01    1745.0       NaN

# %%
dfs_data = survival_data.filter(['DFI.time', 'DFI'])
dfs_data = dfs_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
dfs_data['DFS_E'] = [binary[event] for event in dfs_data['DFI']]
dfs_data['DFS_T'] = [time/30 for time in dfs_data['DFI.time']]
dfs_data.head()
# Out:
#                  DFI.time  DFI  DFS_E      DFS_T
# sample
# TCGA-2Y-A9GS-01     102.0  1.0   True   3.400000
# TCGA-2Y-A9GT-01    1083.0  1.0   True  36.100000
# TCGA-2Y-A9GU-01    1939.0  0.0  False  64.633333
# TCGA-2Y-A9GV-01    2532.0  0.0  False  84.400000
# TCGA-2Y-A9GW-01    1229.0  1.0   True  40.966667

# %%
survival_test = estimation.merge(dfs_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                     Other  Non-inflammatory_Macrophage  alpha-beta_T_Cells  \
# TCGA-FV-A495-01  0.516484                     0.041491            0.065599
# TCGA-CC-A3MB-01  0.436028                     0.037025            0.109933
# TCGA-BC-A3KF-01  0.550941                     0.081541            0.037102
# TCGA-DD-A4NV-01  0.627984                     0.009330            0.153352
# TCGA-BD-A3EP-01  0.396669                     0.070665            0.115707
#
#                  Inflammatory_Macrophage  NK-like_Cells  gamma-delta_T_Cells  \
# TCGA-FV-A495-01                 0.109361       0.044938             0.119505
# TCGA-CC-A3MB-01                 0.079121       0.103977             0.086439
# TCGA-BC-A3KF-01                 0.052791       0.111224             0.093377
# TCGA-DD-A4NV-01                 0.018680       0.055977             0.034729
# TCGA-BD-A3EP-01                 0.160562       0.071016             0.066018
#
#                  Mature_B_Cells  Plasma_Cells  P-value  Correlation      RMSE  \
# TCGA-FV-A495-01        0.020518      0.082104        0     0.850468  0.563478
# TCGA-CC-A3MB-01        0.023214      0.124263        0     0.758718  0.679785
# TCGA-BC-A3KF-01        0.019420      0.053604        0     0.798685  0.615268
# TCGA-DD-A4NV-01        0.034951      0.064996        0     0.730421  0.691170
# TCGA-BD-A3EP-01        0.042557      0.076807        0     0.878135  0.545634
#
#                  DFI.time  DFI  DFS_E      DFS_T
# TCGA-FV-A495-01       1.0  0.0  False   0.033333
# TCGA-CC-A3MB-01     315.0  0.0  False  10.500000
# TCGA-BC-A3KF-01       8.0  0.0  False   0.266667
# TCGA-DD-A4NV-01    2398.0  0.0  False  79.933333
# TCGA-BD-A3EP-01     409.0  0.0  False  13.633333

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#                     Other  Non-inflammatory_Macrophage  alpha-beta_T_Cells  \
# TCGA-DD-A1EC-01  0.156000                     0.019941            0.289520
# TCGA-ED-A5KG-01  0.106271                     0.057622            0.257028
# TCGA-DD-AADM-01  0.450038                     0.038665            0.253969
# TCGA-ED-A7PY-01  0.517899                     0.057981            0.249584
# TCGA-DD-A4NO-01  0.540084                     0.080478            0.249318
# ...                   ...                          ...                 ...
# TCGA-DD-AACL-01  0.191332                     0.096398            0.008189
# TCGA-BC-A69H-01  0.227305                     0.053801            0.005488
# TCGA-DD-AAE0-01  0.094336                     0.070322            0.000774
# TCGA-ED-A66Y-01  0.354005                     0.029462            0.000000
# TCGA-CC-A7IJ-01  0.000000                     0.060712            0.000000
#
#                  Inflammatory_Macrophage  NK-like_Cells  gamma-delta_T_Cells  \
# TCGA-DD-A1EC-01                 0.180371       0.169297             0.000000
# TCGA-ED-A5KG-01                 0.131274       0.051309             0.165829
# TCGA-DD-AADM-01                 0.098189       0.017686             0.014400
# TCGA-ED-A7PY-01                 0.026288       0.109376             0.010133
# TCGA-DD-A4NO-01                 0.041883       0.046293             0.000000
# ...                                  ...            ...                  ...
# TCGA-DD-AACL-01                 0.254729       0.096729             0.116813
# TCGA-BC-A69H-01                 0.214536       0.134922             0.079425
# TCGA-DD-AAE0-01                 0.212714       0.157305             0.171027
# TCGA-ED-A66Y-01                 0.033359       0.190040             0.231474
# TCGA-CC-A7IJ-01                 0.316332       0.125553             0.260086
#
#                  Mature_B_Cells  Plasma_Cells  P-value  Correlation      RMSE  \
# TCGA-DD-A1EC-01        0.054646      0.130225        0     0.526293  0.863337
# TCGA-ED-A5KG-01        0.147179      0.083487        0     0.602669  0.830932
# TCGA-DD-AADM-01        0.033689      0.093365        0     0.762659  0.671021
# TCGA-ED-A7PY-01        0.003522      0.025218        0     0.600675  0.804462
# TCGA-DD-A4NO-01        0.000000      0.041944        0     0.863897  0.538052
# ...                         ...           ...      ...          ...       ...
# TCGA-DD-AACL-01        0.040060      0.195750        0     0.898083  0.526480
# TCGA-BC-A69H-01        0.000000      0.284524        0     0.839411  0.619856
# TCGA-DD-AAE0-01        0.050547      0.242976        0     0.349493  0.946494
# TCGA-ED-A66Y-01        0.027332      0.134326        0     0.287872  0.975671
# TCGA-CC-A7IJ-01        0.041049      0.196269        0     0.704040  0.735797
#
#                  DFI.time  DFI  DFS_E      DFS_T
# TCGA-DD-A1EC-01     299.0  1.0   True   9.966667
# TCGA-ED-A5KG-01     854.0  0.0  False  28.466667
# TCGA-DD-AADM-01      12.0  0.0  False   0.400000
# TCGA-ED-A7PY-01     390.0  0.0  False  13.000000
# TCGA-DD-A4NO-01     990.0  1.0   True  33.000000
# ...                   ...  ...    ...        ...
# TCGA-DD-AACL-01     107.0  0.0  False   3.566667
# TCGA-BC-A69H-01     444.0  0.0  False  14.800000
# TCGA-DD-AAE0-01     555.0  0.0  False  18.500000
# TCGA-ED-A66Y-01     296.0  0.0  False   9.866667
# TCGA-CC-A7IJ-01     382.0  0.0  False  12.733333
#
# [316 rows x 15 columns]

# %%
E = list(survival_reorder['DFS_E'])
mid_point = int(len(E)/2)
E_high = E[:mid_point]
E_low = E[mid_point:]
S = list(survival_reorder['DFS_T'])
S_high = S[:mid_point]
S_low = S[mid_point:]

# %%
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,4)
p
# Out:
# 0.4924

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#e6005c')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#e6005c',label='High Level of alpha-beta T Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of alpha-beta T Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Disease-free Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.DFS.pdf'%selected_cell,format='pdf')

# %%
os_data = survival_data.filter(['OS.time', 'OS'])
os_data = os_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
os_data['OS_E'] = [binary[event] for event in os_data['OS']]
os_data['OS_T'] = [time/30 for time in os_data['OS.time']]
os_data.head()
# Out:
#                  OS.time  OS   OS_E       OS_T
# sample
# TCGA-2Y-A9GS-01    724.0   1   True  24.133333
# TCGA-2Y-A9GT-01   1624.0   1   True  54.133333
# TCGA-2Y-A9GU-01   1939.0   0  False  64.633333
# TCGA-2Y-A9GV-01   2532.0   1   True  84.400000
# TCGA-2Y-A9GW-01   1271.0   1   True  42.366667

# %%
survival_test = estimation.merge(os_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                     Other  Non-inflammatory_Macrophage  alpha-beta_T_Cells  \
# TCGA-FV-A495-01  0.516484                     0.041491            0.065599
# TCGA-CC-A3MB-01  0.436028                     0.037025            0.109933
# TCGA-BC-A3KF-01  0.550941                     0.081541            0.037102
# TCGA-DD-A4NV-01  0.627984                     0.009330            0.153352
# TCGA-CC-A1HT-01  0.029445                     0.041215            0.135512
#
#                  Inflammatory_Macrophage  NK-like_Cells  gamma-delta_T_Cells  \
# TCGA-FV-A495-01                 0.109361       0.044938             0.119505
# TCGA-CC-A3MB-01                 0.079121       0.103977             0.086439
# TCGA-BC-A3KF-01                 0.052791       0.111224             0.093377
# TCGA-DD-A4NV-01                 0.018680       0.055977             0.034729
# TCGA-CC-A1HT-01                 0.330349       0.052573             0.188893
#
#                  Mature_B_Cells  Plasma_Cells  P-value  Correlation      RMSE  \
# TCGA-FV-A495-01        0.020518      0.082104        0     0.850468  0.563478
# TCGA-CC-A3MB-01        0.023214      0.124263        0     0.758718  0.679785
# TCGA-BC-A3KF-01        0.019420      0.053604        0     0.798685  0.615268
# TCGA-DD-A4NV-01        0.034951      0.064996        0     0.730421  0.691170
# TCGA-CC-A1HT-01        0.087843      0.134171        0     0.749928  0.713609
#
#                  OS.time  OS   OS_E       OS_T
# TCGA-FV-A495-01      1.0   0  False   0.033333
# TCGA-CC-A3MB-01    315.0   1   True  10.500000
# TCGA-BC-A3KF-01      8.0   0  False   0.266667
# TCGA-DD-A4NV-01   2398.0   0  False  79.933333
# TCGA-CC-A1HT-01    101.0   1   True   3.366667

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#                     Other  Non-inflammatory_Macrophage  alpha-beta_T_Cells  \
# TCGA-DD-A1EC-01  0.156000                     0.019941            0.289520
# TCGA-BC-4072-01  0.265436                     0.002075            0.288536
# TCGA-BC-A10Q-01  0.011543                     0.002446            0.270149
# TCGA-ED-A5KG-01  0.106271                     0.057622            0.257028
# TCGA-DD-AADM-01  0.450038                     0.038665            0.253969
# ...                   ...                          ...                 ...
# TCGA-DD-AACL-01  0.191332                     0.096398            0.008189
# TCGA-BC-A69H-01  0.227305                     0.053801            0.005488
# TCGA-DD-AAE0-01  0.094336                     0.070322            0.000774
# TCGA-CC-A7IJ-01  0.000000                     0.060712            0.000000
# TCGA-ED-A66Y-01  0.354005                     0.029462            0.000000
#
#                  Inflammatory_Macrophage  NK-like_Cells  gamma-delta_T_Cells  \
# TCGA-DD-A1EC-01                 0.180371       0.169297             0.000000
# TCGA-BC-4072-01                 0.130510       0.054404             0.089129
# TCGA-BC-A10Q-01                 0.268423       0.179086             0.055251
# TCGA-ED-A5KG-01                 0.131274       0.051309             0.165829
# TCGA-DD-AADM-01                 0.098189       0.017686             0.014400
# ...                                  ...            ...                  ...
# TCGA-DD-AACL-01                 0.254729       0.096729             0.116813
# TCGA-BC-A69H-01                 0.214536       0.134922             0.079425
# TCGA-DD-AAE0-01                 0.212714       0.157305             0.171027
# TCGA-CC-A7IJ-01                 0.316332       0.125553             0.260086
# TCGA-ED-A66Y-01                 0.033359       0.190040             0.231474
#
#                  Mature_B_Cells  Plasma_Cells  P-value  Correlation      RMSE  \
# TCGA-DD-A1EC-01        0.054646      0.130225        0     0.526293  0.863337
# TCGA-BC-4072-01        0.061251      0.108658        0     0.560892  0.843081
# TCGA-BC-A10Q-01        0.020030      0.193073        0     0.378499  0.926196
# TCGA-ED-A5KG-01        0.147179      0.083487        0     0.602669  0.830932
# TCGA-DD-AADM-01        0.033689      0.093365        0     0.762659  0.671021
# ...                         ...           ...      ...          ...       ...
# TCGA-DD-AACL-01        0.040060      0.195750        0     0.898083  0.526480
# TCGA-BC-A69H-01        0.000000      0.284524        0     0.839411  0.619856
# TCGA-DD-AAE0-01        0.050547      0.242976        0     0.349493  0.946494
# TCGA-CC-A7IJ-01        0.041049      0.196269        0     0.704040  0.735797
# TCGA-ED-A66Y-01        0.027332      0.134326        0     0.287872  0.975671
#
#                  OS.time  OS   OS_E       OS_T
# TCGA-DD-A1EC-01    602.0   0  False  20.066667
# TCGA-BC-4072-01   1490.0   1   True  49.666667
# TCGA-BC-A10Q-01   1135.0   1   True  37.833333
# TCGA-ED-A5KG-01    854.0   0  False  28.466667
# TCGA-DD-AADM-01     12.0   1   True   0.400000
# ...                  ...  ..    ...        ...
# TCGA-DD-AACL-01    107.0   1   True   3.566667
# TCGA-BC-A69H-01    444.0   0  False  14.800000
# TCGA-DD-AAE0-01    555.0   0  False  18.500000
# TCGA-CC-A7IJ-01    382.0   0  False  12.733333
# TCGA-ED-A66Y-01    296.0   1   True   9.866667
#
# [370 rows x 15 columns]

# %%
E = list(survival_reorder['OS_E'])
mid_point = int(len(E)/2)
E_high = E[:mid_point]
E_low = E[mid_point:]

# %%
S = list(survival_reorder['OS_T'])
S_high = S[:mid_point]
S_low = S[mid_point:]

# %%
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,4)
p
# Out:
# 0.5207

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#3333cc')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#3333cc',label='High Level of alpha-beta_T_Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of alpha-beta_T_Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Overall Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.OS.pdf'%selected_cell,format='pdf')
