# %%
import pandas as pd
import numpy as np
from sksurv.nonparametric import kaplan_meier_estimator as kmf
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test
import matplotlib.patches as mpatches

# %%
selected_cell = 'Portal_endothelial_Cells'

# %%
estimation = pd.read_csv('Non-immune.csv',index_col=0)
estimation.head()
# Out:
#                  Central_venous_LSECs  Cholangiocytes     Other  Hepatocyte  \
# Mixture
# TCGA-FV-A495-01              0.048208        0.082348  0.229907    0.513951
# TCGA-G3-A3CH-11              0.072365        0.057291  0.059977    0.762034
# TCGA-CC-A3MB-01              0.105460        0.105947  0.306659    0.400480
# TCGA-BC-A3KF-01              0.095423        0.057982  0.197635    0.585538
# TCGA-DD-A4NV-01              0.095317        0.013995  0.147109    0.657518
#
#                  Portal_endothelial_Cells  Periportal_LSECs  \
# Mixture
# TCGA-FV-A495-01                  0.052193          0.028028
# TCGA-G3-A3CH-11                  0.002508          0.010815
# TCGA-CC-A3MB-01                  0.010965          0.018600
# TCGA-BC-A3KF-01                  0.023488          0.000000
# TCGA-DD-A4NV-01                  0.026562          0.017952
#
#                  Hepatic_Stellate_Cells  Erythroid_Cells  P-value  \
# Mixture
# TCGA-FV-A495-01                0.026566         0.018798        0
# TCGA-G3-A3CH-11                0.009797         0.025213        0
# TCGA-CC-A3MB-01                0.015033         0.036854        0
# TCGA-BC-A3KF-01                0.005508         0.034425        0
# TCGA-DD-A4NV-01                0.020608         0.020940        0
#
#                  Correlation      RMSE
# Mixture
# TCGA-FV-A495-01     0.936357  0.374260
# TCGA-G3-A3CH-11     0.891445  0.490836
# TCGA-CC-A3MB-01     0.927513  0.428470
# TCGA-BC-A3KF-01     0.893156  0.452923
# TCGA-DD-A4NV-01     0.906726  0.426207

# %%
sample_list = [sample for sample in estimation.index.values if '-01' in sample]
estimation = estimation.reindex(sample_list)

# %%
survival_data = pd.read_csv('survival_LIHC_survival.txt',index_col=0,delimiter='\t')
sample_list = [sample for sample in survival_data.index.values if '-01' in sample]
survival_data = survival_data.reindex(sample_list)
survival_data.head()
# Out:
#                      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  DFI.time  PFI  \
# sample
# TCGA-2V-A95S-01  TCGA-2V-A95S   0      NaN  0.0       NaN  0.0       NaN    0
# TCGA-2Y-A9GS-01  TCGA-2Y-A9GS   1    724.0  1.0     724.0  1.0     102.0    1
# TCGA-2Y-A9GT-01  TCGA-2Y-A9GT   1   1624.0  1.0    1624.0  1.0    1083.0    1
# TCGA-2Y-A9GU-01  TCGA-2Y-A9GU   0   1939.0  0.0    1939.0  0.0    1939.0    0
# TCGA-2Y-A9GV-01  TCGA-2Y-A9GV   1   2532.0  1.0    2532.0  0.0    2532.0    1
#
#                  PFI.time Redaction
# sample
# TCGA-2V-A95S-01       NaN       NaN
# TCGA-2Y-A9GS-01     102.0       NaN
# TCGA-2Y-A9GT-01    1083.0       NaN
# TCGA-2Y-A9GU-01    1939.0       NaN
# TCGA-2Y-A9GV-01    1745.0       NaN

# %%
dfs_data = survival_data.filter(['DFI.time', 'DFI'])
dfs_data = dfs_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
dfs_data['DFS_E'] = [binary[event] for event in dfs_data['DFI']]
dfs_data['DFS_T'] = [time/30 for time in dfs_data['DFI.time']]
dfs_data.head()
# Out:
#                  DFI.time  DFI  DFS_E      DFS_T
# sample
# TCGA-2Y-A9GS-01     102.0  1.0   True   3.400000
# TCGA-2Y-A9GT-01    1083.0  1.0   True  36.100000
# TCGA-2Y-A9GU-01    1939.0  0.0  False  64.633333
# TCGA-2Y-A9GV-01    2532.0  0.0  False  84.400000
# TCGA-2Y-A9GW-01    1229.0  1.0   True  40.966667

# %%
survival_test = estimation.merge(dfs_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                  Central_venous_LSECs  Cholangiocytes     Other  Hepatocyte  \
# TCGA-FV-A495-01              0.048208        0.082348  0.229907    0.513951
# TCGA-CC-A3MB-01              0.105460        0.105947  0.306659    0.400480
# TCGA-BC-A3KF-01              0.095423        0.057982  0.197635    0.585538
# TCGA-DD-A4NV-01              0.095317        0.013995  0.147109    0.657518
# TCGA-BD-A3EP-01              0.089460        0.017993  0.329526    0.404147
#
#                  Portal_endothelial_Cells  Periportal_LSECs  \
# TCGA-FV-A495-01                  0.052193          0.028028
# TCGA-CC-A3MB-01                  0.010965          0.018600
# TCGA-BC-A3KF-01                  0.023488          0.000000
# TCGA-DD-A4NV-01                  0.026562          0.017952
# TCGA-BD-A3EP-01                  0.035101          0.069184
#
#                  Hepatic_Stellate_Cells  Erythroid_Cells  P-value  \
# TCGA-FV-A495-01                0.026566         0.018798        0
# TCGA-CC-A3MB-01                0.015033         0.036854        0
# TCGA-BC-A3KF-01                0.005508         0.034425        0
# TCGA-DD-A4NV-01                0.020608         0.020940        0
# TCGA-BD-A3EP-01                0.026817         0.027771        0
#
#                  Correlation      RMSE  DFI.time  DFI  DFS_E      DFS_T
# TCGA-FV-A495-01     0.936357  0.374260       1.0  0.0  False   0.033333
# TCGA-CC-A3MB-01     0.927513  0.428470     315.0  0.0  False  10.500000
# TCGA-BC-A3KF-01     0.893156  0.452923       8.0  0.0  False   0.266667
# TCGA-DD-A4NV-01     0.906726  0.426207    2398.0  0.0  False  79.933333
# TCGA-BD-A3EP-01     0.717692  0.710705     409.0  0.0  False  13.633333

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#                  Central_venous_LSECs  Cholangiocytes     Other  Hepatocyte  \
# TCGA-DD-A3A6-01              0.060229        0.000000  0.396414    0.000000
# TCGA-CC-A5UD-01              0.049354        0.016352  0.645720    0.073962
# TCGA-DD-AAD5-01              0.116123        0.088611  0.534092    0.065430
# TCGA-ED-A82E-01              0.058947        0.067391  0.617422    0.000000
# TCGA-DD-AAVX-01              0.064011        0.003368  0.234636    0.561189
# ...                               ...             ...       ...         ...
# TCGA-DD-A4NE-01              0.090187        0.053060  0.278048    0.526774
# TCGA-ZP-A9D0-01              0.058946        0.020609  0.187620    0.686857
# TCGA-ZP-A9CZ-01              0.102492        0.056020  0.300930    0.491502
# TCGA-DD-A73G-01              0.085151        0.093540  0.272945    0.500396
# TCGA-DD-A73F-01              0.078545        0.055716  0.232366    0.583198
#
#                  Portal_endothelial_Cells  Periportal_LSECs  \
# TCGA-DD-A3A6-01                  0.126560          0.232675
# TCGA-CC-A5UD-01                  0.101037          0.066478
# TCGA-DD-AAD5-01                  0.100997          0.050725
# TCGA-ED-A82E-01                  0.093619          0.090769
# TCGA-DD-AAVX-01                  0.080554          0.031401
# ...                                   ...               ...
# TCGA-DD-A4NE-01                  0.000000          0.000000
# TCGA-ZP-A9D0-01                  0.000000          0.009578
# TCGA-ZP-A9CZ-01                  0.000000          0.007084
# TCGA-DD-A73G-01                  0.000000          0.000000
# TCGA-DD-A73F-01                  0.000000          0.005576
#
#                  Hepatic_Stellate_Cells  Erythroid_Cells  P-value  \
# TCGA-DD-A3A6-01                0.144611         0.039511        0
# TCGA-CC-A5UD-01                0.011907         0.035191        0
# TCGA-DD-AAD5-01                0.011806         0.032218        0
# TCGA-ED-A82E-01                0.032862         0.038989        0
# TCGA-DD-AAVX-01                0.004991         0.019849        0
# ...                                 ...              ...      ...
# TCGA-DD-A4NE-01                0.021771         0.030159        0
# TCGA-ZP-A9D0-01                0.010277         0.026113        0
# TCGA-ZP-A9CZ-01                0.013885         0.028088        0
# TCGA-DD-A73G-01                0.015837         0.032131        0
# TCGA-DD-A73F-01                0.007892         0.036708        0
#
#                  Correlation      RMSE  DFI.time  DFI  DFS_E       DFS_T
# TCGA-DD-A3A6-01     0.374246  0.932646    3258.0  0.0  False  108.600000
# TCGA-CC-A5UD-01     0.588880  0.891505     182.0  1.0   True    6.066667
# TCGA-DD-AAD5-01     0.543745  0.871151     130.0  1.0   True    4.333333
# TCGA-ED-A82E-01     0.263592  0.966805     408.0  0.0  False   13.600000
# TCGA-DD-AAVX-01     0.630957  0.782517     393.0  1.0   True   13.100000
# ...                      ...       ...       ...  ...    ...         ...
# TCGA-DD-A4NE-01     0.854005  0.526631     190.0  1.0   True    6.333333
# TCGA-ZP-A9D0-01     0.899944  0.439124    1091.0  0.0  False   36.366667
# TCGA-ZP-A9CZ-01     0.874486  0.504321     706.0  0.0  False   23.533333
# TCGA-DD-A73G-01     0.825579  0.564932    3478.0  0.0  False  115.933333
# TCGA-DD-A73F-01     0.849979  0.528002    1085.0  0.0  False   36.166667
#
# [316 rows x 15 columns]

# %%
E = list(survival_reorder['DFS_E'])
mid_point = int(len(E)/2)
E_high = E[:mid_point]
E_low = E[mid_point:]
S = list(survival_reorder['DFS_T'])
S_high = S[:mid_point]
S_low = S[mid_point:]

# %%
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,4)
p
# Out:
# 0.5817

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#e6005c')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#e6005c',label='High Level of Portal Endothelial Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of Portal Endothelial Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Disease-free Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.DFS.pdf'%selected_cell,format='pdf')

# %%
os_data = survival_data.filter(['OS.time', 'OS'])
os_data = os_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
os_data['OS_E'] = [binary[event] for event in os_data['OS']]
os_data['OS_T'] = [time/30 for time in os_data['OS.time']]
os_data.head()
# Out:
#                  OS.time  OS   OS_E       OS_T
# sample
# TCGA-2Y-A9GS-01    724.0   1   True  24.133333
# TCGA-2Y-A9GT-01   1624.0   1   True  54.133333
# TCGA-2Y-A9GU-01   1939.0   0  False  64.633333
# TCGA-2Y-A9GV-01   2532.0   1   True  84.400000
# TCGA-2Y-A9GW-01   1271.0   1   True  42.366667

# %%
survival_test = estimation.merge(os_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                  Central_venous_LSECs  Cholangiocytes     Other  Hepatocyte  \
# TCGA-FV-A495-01              0.048208        0.082348  0.229907    0.513951
# TCGA-CC-A3MB-01              0.105460        0.105947  0.306659    0.400480
# TCGA-BC-A3KF-01              0.095423        0.057982  0.197635    0.585538
# TCGA-DD-A4NV-01              0.095317        0.013995  0.147109    0.657518
# TCGA-CC-A1HT-01              0.072179        0.021915  0.718695    0.009198
#
#                  Portal_endothelial_Cells  Periportal_LSECs  \
# TCGA-FV-A495-01                  0.052193          0.028028
# TCGA-CC-A3MB-01                  0.010965          0.018600
# TCGA-BC-A3KF-01                  0.023488          0.000000
# TCGA-DD-A4NV-01                  0.026562          0.017952
# TCGA-CC-A1HT-01                  0.094734          0.030957
#
#                  Hepatic_Stellate_Cells  Erythroid_Cells  P-value  \
# TCGA-FV-A495-01                0.026566         0.018798        0
# TCGA-CC-A3MB-01                0.015033         0.036854        0
# TCGA-BC-A3KF-01                0.005508         0.034425        0
# TCGA-DD-A4NV-01                0.020608         0.020940        0
# TCGA-CC-A1HT-01                0.034111         0.018211        0
#
#                  Correlation      RMSE  OS.time  OS   OS_E       OS_T
# TCGA-FV-A495-01     0.936357  0.374260      1.0   0  False   0.033333
# TCGA-CC-A3MB-01     0.927513  0.428470    315.0   1   True  10.500000
# TCGA-BC-A3KF-01     0.893156  0.452923      8.0   0  False   0.266667
# TCGA-DD-A4NV-01     0.906726  0.426207   2398.0   0  False  79.933333
# TCGA-CC-A1HT-01     0.769953  0.865544    101.0   1   True   3.366667

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#                  Central_venous_LSECs  Cholangiocytes     Other  Hepatocyte  \
# TCGA-DD-A3A6-01              0.060229        0.000000  0.396414    0.000000
# TCGA-CC-A5UD-01              0.049354        0.016352  0.645720    0.073962
# TCGA-DD-AAD5-01              0.116123        0.088611  0.534092    0.065430
# TCGA-CC-A1HT-01              0.072179        0.021915  0.718695    0.009198
# TCGA-ED-A82E-01              0.058947        0.067391  0.617422    0.000000
# ...                               ...             ...       ...         ...
# TCGA-FV-A4ZQ-01              0.107249        0.039150  0.503642    0.313494
# TCGA-2Y-A9H5-01              0.104455        0.109667  0.238474    0.436450
# TCGA-DD-AADW-01              0.143133        0.160443  0.321204    0.273610
# TCGA-ZP-A9CZ-01              0.102492        0.056020  0.300930    0.491502
# TCGA-ES-A2HS-01              0.064923        0.000000  0.187871    0.658978
#
#                  Portal_endothelial_Cells  Periportal_LSECs  \
# TCGA-DD-A3A6-01                  0.126560          0.232675
# TCGA-CC-A5UD-01                  0.101037          0.066478
# TCGA-DD-AAD5-01                  0.100997          0.050725
# TCGA-CC-A1HT-01                  0.094734          0.030957
# TCGA-ED-A82E-01                  0.093619          0.090769
# ...                                   ...               ...
# TCGA-FV-A4ZQ-01                  0.000000          0.000000
# TCGA-2Y-A9H5-01                  0.000000          0.047629
# TCGA-DD-AADW-01                  0.000000          0.033621
# TCGA-ZP-A9CZ-01                  0.000000          0.007084
# TCGA-ES-A2HS-01                  0.000000          0.056820
#
#                  Hepatic_Stellate_Cells  Erythroid_Cells  P-value  \
# TCGA-DD-A3A6-01                0.144611         0.039511        0
# TCGA-CC-A5UD-01                0.011907         0.035191        0
# TCGA-DD-AAD5-01                0.011806         0.032218        0
# TCGA-CC-A1HT-01                0.034111         0.018211        0
# TCGA-ED-A82E-01                0.032862         0.038989        0
# ...                                 ...              ...      ...
# TCGA-FV-A4ZQ-01                0.007295         0.029170        0
# TCGA-2Y-A9H5-01                0.027251         0.036075        0
# TCGA-DD-AADW-01                0.028189         0.039800        0
# TCGA-ZP-A9CZ-01                0.013885         0.028088        0
# TCGA-ES-A2HS-01                0.005823         0.025585        0
#
#                  Correlation      RMSE  OS.time  OS   OS_E        OS_T
# TCGA-DD-A3A6-01     0.374246  0.932646   3258.0   1   True  108.600000
# TCGA-CC-A5UD-01     0.588880  0.891505    304.0   1   True   10.133333
# TCGA-DD-AAD5-01     0.543745  0.871151   1345.0   0  False   44.833333
# TCGA-CC-A1HT-01     0.769953  0.865544    101.0   1   True    3.366667
# TCGA-ED-A82E-01     0.263592  0.966805    408.0   0  False   13.600000
# ...                      ...       ...      ...  ..    ...         ...
# TCGA-FV-A4ZQ-01     0.861703  0.624751     12.0   0  False    0.400000
# TCGA-2Y-A9H5-01     0.898601  0.457381    555.0   1   True   18.500000
# TCGA-DD-AADW-01     0.792294  0.621647    587.0   0  False   19.566667
# TCGA-ZP-A9CZ-01     0.874486  0.504321    706.0   0  False   23.533333
# TCGA-ES-A2HS-01     0.582123  0.856154    688.0   1   True   22.933333
#
# [370 rows x 15 columns]

# %%
E = list(survival_reorder['OS_E'])
mid_point = int(len(E)/2)
E_high = E[:mid_point]
E_low = E[mid_point:]

# %%
S = list(survival_reorder['OS_T'])
S_high = S[:mid_point]
S_low = S[mid_point:]

# %%
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,4)
p
# Out:
# 0.7317

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#3333cc')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#3333cc',label='High Level of Portal Endothelial Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of Portal Endothelial Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Overall Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.OS.pdf'%selected_cell,format='pdf')
