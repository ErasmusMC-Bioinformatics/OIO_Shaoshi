# %%
import pandas as pd
import numpy as np
from sksurv.nonparametric import kaplan_meier_estimator as kmf
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test
import matplotlib.patches as mpatches

# %%
selected_cell = 'T Cells'

# %%
estimation = pd.read_csv('TCGA-LIHC.Immune.T_Cell.csv',index_col=0)
estimation.head()
# Out:
#                  CD8+ Cells     Tregs  Non-immune cluster  Nk Cells  \
# Mixture
# TCGA-FV-A495-01    0.061526  0.036791            0.688189  0.098637
# TCGA-G3-A3CH-11    0.098691  0.000000            0.738276  0.006164
# TCGA-CC-A3MB-01    0.139905  0.032341            0.480762  0.118661
# TCGA-BC-A3KF-01    0.114993  0.041077            0.596361  0.083589
# TCGA-DD-A4NV-01    0.098896  0.002426            0.660500  0.058329
#
#                  CD4+ Cells   B Cells   Myeloid  Mast Cells  P-value  \
# Mixture
# TCGA-FV-A495-01    0.058827  0.009298  0.044200    0.002532        0
# TCGA-G3-A3CH-11    0.104097  0.000367  0.049163    0.003243        0
# TCGA-CC-A3MB-01    0.094536  0.044451  0.085290    0.004055        0
# TCGA-BC-A3KF-01    0.062153  0.032894  0.067308    0.001626        0
# TCGA-DD-A4NV-01    0.102381  0.027923  0.048503    0.001041        0
#
#                  Correlation      RMSE  Unnamed: 12   T Cells
# Mixture
# TCGA-FV-A495-01     0.886827  0.467952          NaN  0.157144
# TCGA-G3-A3CH-11     0.919957  0.400423          NaN  0.202787
# TCGA-CC-A3MB-01     0.842832  0.582837          NaN  0.266781
# TCGA-BC-A3KF-01     0.791911  0.613901          NaN  0.218223
# TCGA-DD-A4NV-01     0.849245  0.532237          NaN  0.203704

# %%
sample_list = [sample for sample in estimation.index.values if '-01' in sample]
estimation = estimation.reindex(sample_list)

# %%
survival_data = pd.read_csv('survival_LIHC_survival.txt',index_col=0,delimiter='\t')
sample_list = [sample for sample in survival_data.index.values if '-01' in sample]
survival_data = survival_data.reindex(sample_list)
survival_data.head()
# Out:
#                      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  DFI.time  PFI  \
# sample
# TCGA-2V-A95S-01  TCGA-2V-A95S   0      NaN  0.0       NaN  0.0       NaN    0
# TCGA-2Y-A9GS-01  TCGA-2Y-A9GS   1    724.0  1.0     724.0  1.0     102.0    1
# TCGA-2Y-A9GT-01  TCGA-2Y-A9GT   1   1624.0  1.0    1624.0  1.0    1083.0    1
# TCGA-2Y-A9GU-01  TCGA-2Y-A9GU   0   1939.0  0.0    1939.0  0.0    1939.0    0
# TCGA-2Y-A9GV-01  TCGA-2Y-A9GV   1   2532.0  1.0    2532.0  0.0    2532.0    1
#
#                  PFI.time Redaction
# sample
# TCGA-2V-A95S-01       NaN       NaN
# TCGA-2Y-A9GS-01     102.0       NaN
# TCGA-2Y-A9GT-01    1083.0       NaN
# TCGA-2Y-A9GU-01    1939.0       NaN
# TCGA-2Y-A9GV-01    1745.0       NaN

# %%
dfs_data = survival_data.filter(['DFI.time', 'DFI'])
dfs_data = dfs_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
dfs_data['DFS_E'] = [binary[event] for event in dfs_data['DFI']]
dfs_data['DFS_T'] = [time/30 for time in dfs_data['DFI.time']]
dfs_data.head()
# Out:
#                  DFI.time  DFI  DFS_E      DFS_T
# sample
# TCGA-2Y-A9GS-01     102.0  1.0   True   3.400000
# TCGA-2Y-A9GT-01    1083.0  1.0   True  36.100000
# TCGA-2Y-A9GU-01    1939.0  0.0  False  64.633333
# TCGA-2Y-A9GV-01    2532.0  0.0  False  84.400000
# TCGA-2Y-A9GW-01    1229.0  1.0   True  40.966667

# %%
survival_test = estimation.merge(dfs_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                  CD8+ Cells     Tregs  Non-immune cluster  Nk Cells  \
_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['DFS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
optimization
# Out:
# 129

# %%
dfs_cut_level = survival_reorder[selected_cell][optimization]
dfs_cut_level
# Out:
# 0.24545441963390302

# %%
E = list(survival_reorder['DFS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['DFS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 0.00247

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='b')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0.2,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='b',label='High Level of T Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of T Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Disease-free Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.DFS.pdf'%selected_cell,format='pdf')

# %%
os_data = survival_data.filter(['OS.time', 'OS'])
os_data = os_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
os_data['OS_E'] = [binary[event] for event in os_data['OS']]
os_data['OS_T'] = [time/30 for time in os_data['OS.time']]
os_data.head()
# Out:
#                  OS.time  OS   OS_E       OS_T
# sample
# TCGA-2Y-A9GS-01    724.0   1   True  24.133333
# TCGA-2Y-A9GT-01   1624.0   1   True  54.133333
# TCGA-2Y-A9GU-01   1939.0   0  False  64.633333
# TCGA-2Y-A9GV-01   2532.0   1   True  84.400000
# TCGA-2Y-A9GW-01   1271.0   1   True  42.366667

# %%
survival_test = estimation.merge(os_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                  CD8+ Cells     Tregs  Non-immune cluster  Nk Cells  \
# TCGA-FV-A495-01    0.061526  0.036791            0.688189  0.098637
# TCGA-CC-A3MB-01    0.139905  0.032341            0.480762  0.118661
# TCGA-BC-A3KF-01    0.114993  0.041077            0.596361  0.083589
# TCGA-DD-A4NV-01    0.098896  0.002426            0.660500  0.058329
# TCGA-CC-A1HT-01    0.049722  0.125314            0.124946  0.306282
#
#                  CD4+ Cells   B Cells   Myeloid  Mast Cells  P-value  \
# TCGA-FV-A495-01    0.058827  0.009298  0.044200    0.002532        0
# TCGA-CC-A3MB-01    0.094536  0.044451  0.085290    0.004055        0
# TCGA-BC-A3KF-01    0.062153  0.032894  0.067308    0.001626        0
# TCGA-DD-A4NV-01    0.102381  0.027923  0.048503    0.001041        0
# TCGA-CC-A1HT-01    0.066158  0.041490  0.285777    0.000310        0
#
#                  Correlation      RMSE  Unnamed: 12   T Cells  OS.time  OS  \
# TCGA-FV-A495-01     0.886827  0.467952          NaN  0.157144      1.0   0
# TCGA-CC-A3MB-01     0.842832  0.582837          NaN  0.266781    315.0   1
# TCGA-BC-A3KF-01     0.791911  0.613901          NaN  0.218223      8.0   0
# TCGA-DD-A4NV-01     0.849245  0.532237          NaN  0.203704   2398.0   0
# TCGA-CC-A1HT-01     0.588385  0.868008          NaN  0.241194    101.0   1
#
#                   OS_E       OS_T
# TCGA-FV-A495-01  False   0.033333
# TCGA-CC-A3MB-01   True  10.500000
# TCGA-BC-A3KF-01  False   0.266667
# TCGA-DD-A4NV-01  False  79.933333
# TCGA-CC-A1HT-01   True   3.366667

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#                  CD8+ Cells     Tregs  Non-immune cluster  Nk Cells  \
# TCGA-ED-A5KG-01    0.118495  0.014670            0.174160  0.151004
# TCGA-ED-A82E-01    0.069451  0.189070            0.007926  0.284670
# TCGA-DD-AA3A-01    0.041634  0.162648            0.049325  0.274810
# TCGA-DD-A4NA-01    0.131733  0.135572            0.063028  0.230108
# TCGA-CC-5260-01    0.159103  0.117135            0.001558  0.256799
# ...                     ...       ...                 ...       ...
# TCGA-ES-A2HS-01    0.059250  0.005017            0.777708  0.033812
# TCGA-FV-A4ZP-01    0.044040  0.094995            0.461507  0.196832
# TCGA-DD-AADS-01    0.092272  0.028855            0.811724  0.034694
# TCGA-DD-A39V-01    0.055666  0.066544            0.509574  0.154984
# TCGA-ES-A2HT-01    0.052137  0.050124            0.702876  0.102980
#
#                  CD4+ Cells   B Cells   Myeloid  Mast Cells  P-value  \
# TCGA-ED-A5KG-01    0.320050  0.030105  0.191516    0.000000        0
# TCGA-ED-A82E-01    0.187896  0.073192  0.187795    0.000000        0
# TCGA-DD-AA3A-01    0.222474  0.111505  0.137604    0.000000        0
# TCGA-DD-A4NA-01    0.151409  0.095219  0.190595    0.002336        0
# TCGA-CC-5260-01    0.135604  0.073176  0.256501    0.000124        0
# ...                     ...       ...       ...         ...      ...
# TCGA-ES-A2HS-01    0.080452  0.031376  0.009152    0.003233        0
# TCGA-FV-A4ZP-01    0.004797  0.055024  0.141785    0.001020        0
# TCGA-DD-AADS-01    0.020804  0.000000  0.008363    0.003289        0
# TCGA-DD-A39V-01    0.018001  0.037454  0.156106    0.001671        0
# TCGA-ES-A2HT-01    0.020075  0.031233  0.037398    0.003178        0
#
#                  Correlation      RMSE  Unnamed: 12   T Cells  OS.time  OS  \
# TCGA-ED-A5KG-01     0.649268  0.842549          NaN  0.453215    854.0   0
# TCGA-ED-A82E-01     0.243913  0.975363          NaN  0.446417    408.0   0
# TCGA-DD-AA3A-01     0.401834  0.946114          NaN  0.426755    410.0   1
# TCGA-DD-A4NA-01     0.447747  0.931051          NaN  0.418713   1008.0   0
# TCGA-CC-5260-01     0.309267  0.960866          NaN  0.411842     87.0   1
# ...                      ...       ...          ...       ...      ...  ..
# TCGA-ES-A2HS-01     0.886410  0.479375          NaN  0.144719    688.0   1
# TCGA-FV-A4ZP-01     0.677649  0.739241          NaN  0.143832   2486.0   1
# TCGA-DD-AADS-01     0.874494  0.512804          NaN  0.141930    474.0   0
# TCGA-DD-A39V-01     0.712411  0.704333          NaN  0.140211    643.0   1
# TCGA-ES-A2HT-01     0.822444  0.577189          NaN  0.122336    438.0   1
#
#                   OS_E       OS_T
# TCGA-ED-A5KG-01  False  28.466667
# TCGA-ED-A82E-01  False  13.600000
# TCGA-DD-AA3A-01   True  13.666667
# TCGA-DD-A4NA-01  False  33.600000
# TCGA-CC-5260-01   True   2.900000
# ...                ...        ...
# TCGA-ES-A2HS-01   True  22.933333
# TCGA-FV-A4ZP-01   True  82.866667
# TCGA-DD-AADS-01  False  15.800000
# TCGA-DD-A39V-01   True  21.433333
# TCGA-ES-A2HT-01   True  14.600000
#
# [370 rows x 17 columns]

# %%
running_length = len(survival_reorder)

logrank_tests = []
cut_points = []

for i in range(running_length):
    cut_point = int(i+1)
    E = list(survival_reorder['OS_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['OS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
optimization
# Out:
# 177

# %%
os_cut_level = survival_reorder[selected_cell][optimization]
os_cut_level
# Out:
# 0.237766753867637

# %%
E = list(survival_reorder['OS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['OS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 0.03838

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='b')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0.2,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='b',label='High Level of T Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of T Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Overall Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.OS.pdf'%selected_cell,format='pdf')

# %%
estimation = estimation.sort_values(selected_cell,ascending=False)
x = []
y = []
for key,value in enumerate(estimation[selected_cell]):
    x.append(key)
    y.append(value)

# %%
plt.figure(figsize=(6,6))
plt.scatter(x,y,color='orange')
plt.axhline(y=os_cut_level, xmin=0, xmax=100,color='k')
plt.axhline(y=dfs_cut_level, xmin=0, xmax=100,color='b')
plt.ylabel('Estimated Cell Fraction',fontsize=15)
plt.title('Cutting Point - T Cells',fontsize=15)
dfs_patch = mpatches.Patch(color='b',label='DFS Cutting Level')
os_patch = mpatches.Patch(color='k',label='OS Cutting Level')
plt.legend(handles=[dfs_patch,os_patch],fontsize=12)
plt.savefig('Cutting_Point.%s'%selected_cell,format='pdf')
