# %%
import pandas as pd
import numpy as np
from sksurv.nonparametric import kaplan_meier_estimator as kmf
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test
import matplotlib.patches as mpatches

# %%
selected_cell = 'LVECt'

# %%
estimation = pd.read_csv('TCGA-LIHC.Endothelium.csv',index_col=0)
estimation.head()
# Out:
#                     LVECt     Other      LSEC  Hepatocytes      LVEC  \
# Mixture
# TCGA-FV-A495-01  0.029261  0.321348  0.048555     0.223134  0.115910
# TCGA-G3-A3CH-11  0.000000  0.242231  0.110265     0.363060  0.107582
# TCGA-CC-A3MB-01  0.088565  0.155909  0.068922     0.086031  0.073978
# TCGA-BC-A3KF-01  0.000000  0.400355  0.077137     0.132735  0.092583
# TCGA-DD-A4NV-01  0.000000  0.184242  0.058940     0.261421  0.250689
#
#                  Carcinoma  P-value  Correlation      RMSE
# Mixture
# TCGA-FV-A495-01   0.261792        0     0.856237  0.598103
# TCGA-G3-A3CH-11   0.176862        0     0.923377  0.393501
# TCGA-CC-A3MB-01   0.526595        0     0.762892  0.828435
# TCGA-BC-A3KF-01   0.297190        0     0.802159  0.743401
# TCGA-DD-A4NV-01   0.244708        0     0.817326  0.604757

# %%
sample_list = [sample for sample in estimation.index.values if '-01' in sample]
estimation = estimation.reindex(sample_list)

# %%
survival_data = pd.read_csv('survival_LIHC_survival.txt',index_col=0,delimiter='\t')
sample_list = [sample for sample in survival_data.index.values if '-01' in sample]
survival_data = survival_data.reindex(sample_list)
survival_data.head()
# Out:
#                      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  DFI.time  PFI  \
# sample
# TCGA-2V-A95S-01  TCGA-2V-A95S   0      NaN  0.0       NaN  0.0       NaN    0
# TCGA-2Y-A9GS-01  TCGA-2Y-A9GS   1    724.0  1.0     724.0  1.0     102.0    1
# TCGA-2Y-A9GT-01  TCGA-2Y-A9GT   1   1624.0  1.0    1624.0  1.0    1083.0    1
# TCGA-2Y-A9GU-01  TCGA-2Y-A9GU   0   1939.0  0.0    1939.0  0.0    1939.0    0
# TCGA-2Y-A9GV-01  TCGA-2Y-A9GV   1   2532.0  1.0    2532.0  0.0    2532.0    1
#
#                  PFI.time Redaction
# sample
# TCGA-2V-A95S-01       NaN       NaN
# TCGA-2Y-A9GS-01     102.0       NaN
# TCGA-2Y-A9GT-01    1083.0       NaN
# TCGA-2Y-A9GU-01    1939.0       NaN
# TCGA-2Y-A9GV-01    1745.0       NaN

# %%
dfs_data = survival_data.filter(['DFI.time', 'DFI'])
dfs_data = dfs_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
dfs_data['DFS_E'] = [binary[event] for event in dfs_data['DFI']]
dfs_data['DFS_T'] = [time/30 for time in dfs_data['DFI.time']]
dfs_data.head()
# Out:
#                  DFI.time  DFI  DFS_E      DFS_T
# sample
# TCGA-2Y-A9GS-01     102.0  1.0   True   3.400000
# TCGA-2Y-A9GT-01    1083.0  1.0   True  36.100000
# TCGA-2Y-A9GU-01    1939.0  0.0  False  64.633333
# TCGA-2Y-A9GV-01    2532.0  0.0  False  84.400000
# TCGA-2Y-A9GW-01    1229.0  1.0   True  40.966667

# %%
survival_test = estimation.merge(dfs_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                     LVECt     Other      LSEC  Hepatocytes      LVEC  \
# TCGA-FV-A495-01  0.029261  0.321348  0.048555     0.223134  0.115910
# TCGA-CC-A3MB-01  0.088565  0.155909  0.068922     0.086031  0.073978
# TCGA-BC-A3KF-01  0.000000  0.400355  0.077137     0.132735  0.092583
# TCGA-DD-A4NV-01  0.000000  0.184242  0.058940     0.261421  0.250689
# TCGA-BD-A3EP-01  0.037617  0.427776  0.046446     0.096096  0.119377
#
#                  Carcinoma  P-value  Correlation      RMSE  DFI.time  DFI  \
# TCGA-FV-A495-01   0.261792        0     0.856237  0.598103       1.0  0.0
# TCGA-CC-A3MB-01   0.526595        0     0.762892  0.828435     315.0  0.0
# TCGA-BC-A3KF-01   0.297190        0     0.802159  0.743401       8.0  0.0
# TCGA-DD-A4NV-01   0.244708        0     0.817326  0.604757    2398.0  0.0
# TCGA-BD-A3EP-01   0.272687        0     0.753843  0.807542     409.0  0.0
#
#                  DFS_E      DFS_T
# TCGA-FV-A495-01  False   0.033333
# TCGA-CC-A3MB-01  False  10.500000
# TCGA-BC-A3KF-01  False   0.266667
# TCGA-DD-A4NV-01  False  79.933333
# TCGA-BD-A3EP-01  False  13.633333

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder.head()
# Out:
#                     LVECt     Other      LSEC  Hepatocytes      LVEC  \
# TCGA-CC-A7II-01  0.262622  0.433085  0.000000     0.001378  0.010913
# TCGA-DD-A118-01  0.243157  0.053379  0.061951     0.137833  0.000000
# TCGA-DD-AADW-01  0.221910  0.158164  0.060686     0.056894  0.010678
# TCGA-5C-A9VG-01  0.217606  0.437952  0.053639     0.068519  0.000000
# TCGA-FV-A3I0-01  0.206089  0.112903  0.005802     0.000000  0.016736
#
#                  Carcinoma  P-value  Correlation      RMSE  DFI.time  DFI  \
# TCGA-CC-A7II-01   0.292002        0     0.555539  0.920360     278.0  1.0
# TCGA-DD-A118-01   0.503680        0     0.711549  0.785350     658.0  1.0
# TCGA-DD-AADW-01   0.491668        0     0.656422  0.886527     386.0  1.0
# TCGA-5C-A9VG-01   0.222283        0     0.659524  0.861519     328.0  0.0
# TCGA-FV-A3I0-01   0.658470        0     0.566040  0.936619     159.0  1.0
#
#                  DFS_E      DFS_T
# TCGA-CC-A7II-01   True   9.266667
# TCGA-DD-A118-01   True  21.933333
# TCGA-DD-AADW-01   True  12.866667
# TCGA-5C-A9VG-01  False  10.933333
# TCGA-FV-A3I0-01   True   5.300000

# %%
running_length = len(survival_reorder)

logrank_tests = []
cut_points = []

for i in range(running_length):
    cut_point = int(i+1)
    E = list(survival_reorder['DFS_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['DFS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
optimization
# Out:
# 237

# %%
dfs_cut_level = survival_reorder[selected_cell][optimization]
dfs_cut_level
# Out:
# 0.0

# %%
E = list(survival_reorder['DFS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['DFS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 4e-05

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#e6005c')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#e6005c',label='High Level of LVECts (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of LVECts (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Disease-free Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.DFS.pdf'%selected_cell,format='pdf')

# %%
os_data = survival_data.filter(['OS.time', 'OS'])
os_data = os_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
os_data['OS_E'] = [binary[event] for event in os_data['OS']]
os_data['OS_T'] = [time/30 for time in os_data['OS.time']]
os_data.head()
# Out:
#                  OS.time  OS   OS_E       OS_T
# sample
# TCGA-2Y-A9GS-01    724.0   1   True  24.133333
# TCGA-2Y-A9GT-01   1624.0   1   True  54.133333
# TCGA-2Y-A9GU-01   1939.0   0  False  64.633333
# TCGA-2Y-A9GV-01   2532.0   1   True  84.400000
# TCGA-2Y-A9GW-01   1271.0   1   True  42.366667

# %%
survival_test = estimation.merge(os_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                     LVECt     Other      LSEC  Hepatocytes      LVEC  \
# TCGA-FV-A495-01  0.029261  0.321348  0.048555     0.223134  0.115910
# TCGA-CC-A3MB-01  0.088565  0.155909  0.068922     0.086031  0.073978
# TCGA-BC-A3KF-01  0.000000  0.400355  0.077137     0.132735  0.092583
# TCGA-DD-A4NV-01  0.000000  0.184242  0.058940     0.261421  0.250689
# TCGA-CC-A1HT-01  0.044137  0.445313  0.006798     0.001061  0.185631
#
#                  Carcinoma  P-value  Correlation      RMSE  OS.time  OS  \
# TCGA-FV-A495-01   0.261792        0     0.856237  0.598103      1.0   0
# TCGA-CC-A3MB-01   0.526595        0     0.762892  0.828435    315.0   1
# TCGA-BC-A3KF-01   0.297190        0     0.802159  0.743401      8.0   0
# TCGA-DD-A4NV-01   0.244708        0     0.817326  0.604757   2398.0   0
# TCGA-CC-A1HT-01   0.317060        0     0.699909  0.897641    101.0   1
#
#                   OS_E       OS_T
# TCGA-FV-A495-01  False   0.033333
# TCGA-CC-A3MB-01   True  10.500000
# TCGA-BC-A3KF-01  False   0.266667
# TCGA-DD-A4NV-01  False  79.933333
# TCGA-CC-A1HT-01   True   3.366667

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#                     LVECt     Other      LSEC  Hepatocytes      LVEC  \
# TCGA-CC-A7II-01  0.262622  0.433085  0.000000     0.001378  0.010913
# TCGA-DD-A118-01  0.243157  0.053379  0.061951     0.137833  0.000000
# TCGA-DD-AADW-01  0.221910  0.158164  0.060686     0.056894  0.010678
# TCGA-CC-5261-01  0.220467  0.222033  0.032686     0.037824  0.041257
# TCGA-5C-A9VG-01  0.217606  0.437952  0.053639     0.068519  0.000000
# ...                   ...       ...       ...          ...       ...
# TCGA-FV-A496-01  0.000000  0.385300  0.042347     0.173289  0.134512
# TCGA-2Y-A9H2-01  0.000000  0.112912  0.013081     0.027241  0.186717
# TCGA-ZS-A9CE-01  0.000000  0.171448  0.057899     0.285327  0.127261
# TCGA-DD-A4NQ-01  0.000000  0.439924  0.043122     0.064256  0.121619
# TCGA-DD-A115-01  0.000000  0.143469  0.062740     0.267000  0.229873
#
#                  Carcinoma  P-value  Correlation      RMSE  OS.time  OS  \
# TCGA-CC-A7II-01   0.292002        0     0.555539  0.920360    399.0   0
# TCGA-DD-A118-01   0.503680        0     0.711549  0.785350   3437.0   0
# TCGA-DD-AADW-01   0.491668        0     0.656422  0.886527    587.0   0
# TCGA-CC-5261-01   0.445733        0     0.687567  0.896589     97.0   1
# TCGA-5C-A9VG-01   0.222283        0     0.659524  0.861519    328.0   0
# ...                    ...      ...          ...       ...      ...  ..
# TCGA-FV-A496-01   0.264552        0     0.753162  0.726008     10.0   0
# TCGA-2Y-A9H2-01   0.660049        0     0.752541  0.900168   1731.0   0
# TCGA-ZS-A9CE-01   0.358066        0     0.832803  0.572158   1241.0   0
# TCGA-DD-A4NQ-01   0.331079        0     0.798953  0.829469    373.0   1
# TCGA-DD-A115-01   0.296918        0     0.803416  0.616055   2542.0   1
#
#                   OS_E        OS_T
# TCGA-CC-A7II-01  False   13.300000
# TCGA-DD-A118-01  False  114.566667
# TCGA-DD-AADW-01  False   19.566667
# TCGA-CC-5261-01   True    3.233333
# TCGA-5C-A9VG-01  False   10.933333
# ...                ...         ...
# TCGA-FV-A496-01  False    0.333333
# TCGA-2Y-A9H2-01  False   57.700000
# TCGA-ZS-A9CE-01  False   41.366667
# TCGA-DD-A4NQ-01   True   12.433333
# TCGA-DD-A115-01   True   84.733333
#
# [370 rows x 13 columns]

# %%
running_length = len(survival_reorder)

logrank_tests = []
cut_points = []

for i in range(running_length):
    cut_point = int(i+1)
    E = list(survival_reorder['OS_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['OS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
#optimization = int(len(E)/2)

# %%
os_cut_level = survival_reorder[selected_cell][optimization]
os_cut_level
# Out:
# 0.0

# %%
E = list(survival_reorder['OS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['OS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 0.00859

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='#3333cc')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='#3333cc',label='High Level of LVECts (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of LVECts (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.76, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Overall Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.OS.pdf'%selected_cell,format='pdf')

# %%
estimation = estimation.sort_values(selected_cell,ascending=False)
x = []
y = []
for key,value in enumerate(estimation[selected_cell]):
    x.append(key)
    y.append(value)

# %%
plt.figure(figsize=(6,6))
plt.scatter(x,y,color='orange')
plt.axhline(y=os_cut_level, xmin=0, xmax=100,color='#3333cc')
plt.axhline(y=dfs_cut_level, xmin=0, xmax=100,color='#e6005c')
plt.ylabel('Estimated Cell Fraction',fontsize=15)
plt.xlabel('TCGA-LIHC Cohort',fontsize=15)
plt.title('Cutting Point - LVECts',fontsize=15)
dfs_patch = mpatches.Patch(color='#e6005c',label='DFS Cutting Level')
os_patch = mpatches.Patch(color='#3333cc',label='OS Cutting Level')
plt.legend(handles=[dfs_patch,os_patch],fontsize=12)
#plt.yscale("log")
plt.savefig('Cutting_Point.%s'%selected_cell,format='pdf')
