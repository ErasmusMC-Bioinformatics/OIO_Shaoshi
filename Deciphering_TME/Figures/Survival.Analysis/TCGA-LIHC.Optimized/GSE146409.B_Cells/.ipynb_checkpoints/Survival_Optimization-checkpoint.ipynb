# %%
import pandas as pd
import numpy as np
from sksurv.nonparametric import kaplan_meier_estimator as kmf
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test
import matplotlib.patches as mpatches

# %%
selected_cell = 'B cells'

# %%
estimation = pd.read_csv('TCGA-LIHC.Immune.csv',index_col=0)
estimation.head()
# Out:
#                     Other  Kupffer cells       TM1      SAMs   T cells  \
# Mixture
# TCGA-FV-A495-01  0.766988       0.023547  0.006748  0.148337  0.005788
# TCGA-G3-A3CH-11  0.865737       0.033286  0.008331  0.032900  0.003808
# TCGA-CC-A3MB-01  0.719061       0.009895  0.013096  0.100181  0.012556
# TCGA-BC-A3KF-01  0.617540       0.103642  0.015847  0.061157  0.007262
# TCGA-DD-A4NV-01  0.752746       0.000000  0.017130  0.101313  0.000000
#
#                      cDC2      cDC1   B cells  P-value  Correlation      RMSE
# Mixture
# TCGA-FV-A495-01  0.019714  0.017748  0.011130        0     0.863320  0.512318
# TCGA-G3-A3CH-11  0.052007  0.003931  0.000000        0     0.917988  0.408080
# TCGA-CC-A3MB-01  0.082132  0.025423  0.037657        0     0.824934  0.574780
# TCGA-BC-A3KF-01  0.133024  0.025164  0.036365        0     0.776250  0.635085
# TCGA-DD-A4NV-01  0.073394  0.016744  0.038674        0     0.788129  0.618510

# %%
sample_list = [sample for sample in estimation.index.values if '-01' in sample]
estimation = estimation.reindex(sample_list)

# %%
survival_data = pd.read_csv('survival_LIHC_survival.txt',index_col=0,delimiter='\t')
sample_list = [sample for sample in survival_data.index.values if '-01' in sample]
survival_data = survival_data.reindex(sample_list)
survival_data.head()
# Out:
#                      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  DFI.time  PFI  \
# sample
# TCGA-2V-A95S-01  TCGA-2V-A95S   0      NaN  0.0       NaN  0.0       NaN    0
# TCGA-2Y-A9GS-01  TCGA-2Y-A9GS   1    724.0  1.0     724.0  1.0     102.0    1
# TCGA-2Y-A9GT-01  TCGA-2Y-A9GT   1   1624.0  1.0    1624.0  1.0    1083.0    1
# TCGA-2Y-A9GU-01  TCGA-2Y-A9GU   0   1939.0  0.0    1939.0  0.0    1939.0    0
# TCGA-2Y-A9GV-01  TCGA-2Y-A9GV   1   2532.0  1.0    2532.0  0.0    2532.0    1
#
#                  PFI.time Redaction
# sample
# TCGA-2V-A95S-01       NaN       NaN
# TCGA-2Y-A9GS-01     102.0       NaN
# TCGA-2Y-A9GT-01    1083.0       NaN
# TCGA-2Y-A9GU-01    1939.0       NaN
# TCGA-2Y-A9GV-01    1745.0       NaN

# %%
dfs_data = survival_data.filter(['DFI.time', 'DFI'])
dfs_data = dfs_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
dfs_data['DFS_E'] = [binary[event] for event in dfs_data['DFI']]
dfs_data['DFS_T'] = [time/30 for time in dfs_data['DFI.time']]
dfs_data.head()
# Out:
#                  DFI.time  DFI  DFS_E      DFS_T
# sample
# TCGA-2Y-A9GS-01     102.0  1.0   True   3.400000
# TCGA-2Y-A9GT-01    1083.0  1.0   True  36.100000
# TCGA-2Y-A9GU-01    1939.0  0.0  False  64.633333
# TCGA-2Y-A9GV-01    2532.0  0.0  False  84.400000
# TCGA-2Y-A9GW-01    1229.0  1.0   True  40.966667

# %%
survival_test = estimation.merge(dfs_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                     Other  Kupffer cells       TM1      SAMs   T cells  \
# TCGA-FV-A495-01  0.766988       0.023547  0.006748  0.148337  0.005788
# TCGA-CC-A3MB-01  0.719061       0.009895  0.013096  0.100181  0.012556
# TCGA-BC-A3KF-01  0.617540       0.103642  0.015847  0.061157  0.007262
# TCGA-DD-A4NV-01  0.752746       0.000000  0.017130  0.101313  0.000000
# TCGA-BD-A3EP-01  0.609699       0.167945  0.034234  0.101201  0.003141
#
#                      cDC2      cDC1   B cells  P-value  Correlation      RMSE  \
# TCGA-FV-A495-01  0.019714  0.017748  0.011130        0     0.863320  0.512318
# TCGA-CC-A3MB-01  0.082132  0.025423  0.037657        0     0.824934  0.574780
# TCGA-BC-A3KF-01  0.133024  0.025164  0.036365        0     0.776250  0.635085
# TCGA-DD-A4NV-01  0.073394  0.016744  0.038674        0     0.788129  0.618510
# TCGA-BD-A3EP-01  0.039687  0.019095  0.024998        0     0.781027  0.626740
#
#                  DFI.time  DFI  DFS_E      DFS_T
# TCGA-FV-A495-01       1.0  0.0  False   0.033333
# TCGA-CC-A3MB-01     315.0  0.0  False  10.500000
# TCGA-BC-A3KF-01       8.0  0.0  False   0.266667
# TCGA-DD-A4NV-01    2398.0  0.0  False  79.933333
# TCGA-BD-A3EP-01     409.0  0.0  False  13.633333

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder.head()
# Out:
#                     Other  Kupffer cells       TM1      SAMs   T cells  \
# TCGA-FV-A3I0-01  0.345585       0.000000  0.023527  0.217579  0.001436
# TCGA-CC-A7IJ-01  0.048366       0.139653  0.045739  0.165968  0.132058
# TCGA-CC-A7II-01  0.311776       0.000000  0.000000  0.377727  0.110866
# TCGA-DD-AA3A-01  0.253124       0.000000  0.032396  0.286238  0.130382
# TCGA-ZP-A9D2-01  0.528211       0.000000  0.000000  0.320824  0.003082
#
#                      cDC2      cDC1   B cells  P-value  Correlation      RMSE  \
# TCGA-FV-A3I0-01  0.248184  0.000000  0.163688        0     0.295783  0.988277
# TCGA-CC-A7IJ-01  0.261200  0.056445  0.150571        0     0.502750  0.872494
# TCGA-CC-A7II-01  0.000000  0.056463  0.143167        0     0.273871  1.027283
# TCGA-DD-AA3A-01  0.114210  0.046625  0.137026        0     0.447203  0.899450
# TCGA-ZP-A9D2-01  0.014343  0.016183  0.117357        0     0.701186  0.714464
#
#                  DFI.time  DFI  DFS_E      DFS_T
# TCGA-FV-A3I0-01     159.0  1.0   True   5.300000
# TCGA-CC-A7IJ-01     382.0  0.0  False  12.733333
# TCGA-CC-A7II-01     278.0  1.0   True   9.266667
# TCGA-DD-AA3A-01     410.0  0.0  False  13.666667
# TCGA-ZP-A9D2-01     315.0  1.0   True  10.500000

# %%
running_length = len(survival_reorder)

logrank_tests = []
cut_points = []

for i in range(running_length):
    cut_point = int(i+1)
    E = list(survival_reorder['DFS_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['DFS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
optimization
# Out:
# 16

# %%
dfs_cut_level = survival_reorder[selected_cell][optimization]
dfs_cut_level
# Out:
# 0.0789443878127167

# %%
E = list(survival_reorder['DFS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['DFS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 0.0109

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='b')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0.2,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='b',label='High Level of B Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of B Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Disease-free Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.DFS.pdf'%selected_cell,format='pdf')

# %%
os_data = survival_data.filter(['OS.time', 'OS'])
os_data = os_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
os_data['OS_E'] = [binary[event] for event in os_data['OS']]
os_data['OS_T'] = [time/30 for time in os_data['OS.time']]
os_data.head()
# Out:
#                  OS.time  OS   OS_E       OS_T
# sample
# TCGA-2Y-A9GS-01    724.0   1   True  24.133333
# TCGA-2Y-A9GT-01   1624.0   1   True  54.133333
# TCGA-2Y-A9GU-01   1939.0   0  False  64.633333
# TCGA-2Y-A9GV-01   2532.0   1   True  84.400000
# TCGA-2Y-A9GW-01   1271.0   1   True  42.366667

# %%
survival_test = estimation.merge(os_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                     Other  Kupffer cells       TM1      SAMs   T cells  \
# TCGA-FV-A495-01  0.766988       0.023547  0.006748  0.148337  0.005788
# TCGA-CC-A3MB-01  0.719061       0.009895  0.013096  0.100181  0.012556
# TCGA-BC-A3KF-01  0.617540       0.103642  0.015847  0.061157  0.007262
# TCGA-DD-A4NV-01  0.752746       0.000000  0.017130  0.101313  0.000000
# TCGA-CC-A1HT-01  0.419074       0.094199  0.078942  0.149734  0.034305
#
#                      cDC2      cDC1   B cells  P-value  Correlation      RMSE  \
# TCGA-FV-A495-01  0.019714  0.017748  0.011130        0     0.863320  0.512318
# TCGA-CC-A3MB-01  0.082132  0.025423  0.037657        0     0.824934  0.574780
# TCGA-BC-A3KF-01  0.133024  0.025164  0.036365        0     0.776250  0.635085
# TCGA-DD-A4NV-01  0.073394  0.016744  0.038674        0     0.788129  0.618510
# TCGA-CC-A1HT-01  0.162842  0.008591  0.052312        0     0.718804  0.698507
#
#                  OS.time  OS   OS_E       OS_T
# TCGA-FV-A495-01      1.0   0  False   0.033333
# TCGA-CC-A3MB-01    315.0   1   True  10.500000
# TCGA-BC-A3KF-01      8.0   0  False   0.266667
# TCGA-DD-A4NV-01   2398.0   0  False  79.933333
# TCGA-CC-A1HT-01    101.0   1   True   3.366667

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#                     Other  Kupffer cells       TM1      SAMs   T cells  \
# TCGA-FV-A3I0-01  0.345585       0.000000  0.023527  0.217579  0.001436
# TCGA-CC-A7IJ-01  0.048366       0.139653  0.045739  0.165968  0.132058
# TCGA-CC-A7II-01  0.311776       0.000000  0.000000  0.377727  0.110866
# TCGA-DD-AA3A-01  0.253124       0.000000  0.032396  0.286238  0.130382
# TCGA-ZP-A9D2-01  0.528211       0.000000  0.000000  0.320824  0.003082
# ...                   ...            ...       ...       ...       ...
# TCGA-BC-A110-01  0.842403       0.000000  0.035103  0.048832  0.000000
# TCGA-WX-AA46-01  0.855509       0.016981  0.040073  0.052663  0.006434
# TCGA-DD-AADS-01  0.766982       0.029211  0.000000  0.138459  0.013669
# TCGA-UB-AA0V-01  0.869595       0.000000  0.020438  0.079606  0.000000
# TCGA-BC-A10X-01  0.814748       0.000000  0.055494  0.081190  0.000000
#
#                      cDC2      cDC1   B cells  P-value  Correlation      RMSE  \
# TCGA-FV-A3I0-01  0.248184  0.000000  0.163688        0     0.295783  0.988277
# TCGA-CC-A7IJ-01  0.261200  0.056445  0.150571        0     0.502750  0.872494
# TCGA-CC-A7II-01  0.000000  0.056463  0.143167        0     0.273871  1.027283
# TCGA-DD-AA3A-01  0.114210  0.046625  0.137026        0     0.447203  0.899450
# TCGA-ZP-A9D2-01  0.014343  0.016183  0.117357        0     0.701186  0.714464
# ...                   ...       ...       ...      ...          ...       ...
# TCGA-BC-A110-01  0.073662  0.000000  0.000000        0     0.881966  0.478875
# TCGA-WX-AA46-01  0.028340  0.000000  0.000000        0     0.903735  0.437599
# TCGA-DD-AADS-01  0.037500  0.014180  0.000000        0     0.797095  0.606437
# TCGA-UB-AA0V-01  0.030361  0.000000  0.000000        0     0.923659  0.395724
# TCGA-BC-A10X-01  0.048569  0.000000  0.000000        0     0.903385  0.443321
#
#                  OS.time  OS   OS_E       OS_T
# TCGA-FV-A3I0-01    848.0   0  False  28.266667
# TCGA-CC-A7IJ-01    382.0   0  False  12.733333
# TCGA-CC-A7II-01    399.0   0  False  13.300000
# TCGA-DD-AA3A-01    410.0   1   True  13.666667
# TCGA-ZP-A9D2-01    765.0   1   True  25.500000
# ...                  ...  ..    ...        ...
# TCGA-BC-A110-01   2116.0   1   True  70.533333
# TCGA-WX-AA46-01    756.0   0  False  25.200000
# TCGA-DD-AADS-01    474.0   0  False  15.800000
# TCGA-UB-AA0V-01    314.0   0  False  10.466667
# TCGA-BC-A10X-01    770.0   1   True  25.666667
#
# [370 rows x 15 columns]

# %%
running_length = len(survival_reorder)

logrank_tests = []
cut_points = []

for i in range(running_length):
    cut_point = int(i+1)
    E = list(survival_reorder['OS_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['OS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
optimization
# Out:
# 15

# %%
os_cut_level = survival_reorder[selected_cell][optimization]
os_cut_level
# Out:
# 0.0825760148539189

# %%
E = list(survival_reorder['OS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['OS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 0.00214

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='b')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0.2,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='b',label='High Level of B Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of B Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Overall Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.OS.pdf'%selected_cell,format='pdf')

# %%
estimation = estimation.sort_values(selected_cell,ascending=False)
x = []
y = []
for key,value in enumerate(estimation[selected_cell]):
    x.append(key)
    y.append(value)

# %%
plt.figure(figsize=(6,6))
plt.scatter(x,y,color='orange')
plt.axhline(y=os_cut_level, xmin=0, xmax=100,color='k')
plt.axhline(y=dfs_cut_level, xmin=0, xmax=100,color='b')
plt.ylabel('Estimated Cell Fraction',fontsize=15)
plt.title('Cutting Point - B Cells',fontsize=15)
dfs_patch = mpatches.Patch(color='b',label='DFS Cutting Level')
os_patch = mpatches.Patch(color='k',label='OS Cutting Level')
plt.legend(handles=[dfs_patch,os_patch],fontsize=12)
plt.savefig('Cutting_Point.%s'%selected_cell,format='pdf')
