# %%
import pandas as pd
import numpy as np
from sksurv.nonparametric import kaplan_meier_estimator as kmf
import matplotlib.pyplot as plt
from lifelines.statistics import logrank_test
import matplotlib.patches as mpatches

# %%
selected_cell = 'Endothelial Cells'

# %%
estimation = pd.read_csv('TCGA-LIHC.Non-immune.csv',index_col=0)
estimation.head()
# Out:
#                  Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# Mixture
# TCGA-FV-A495-01        0.092709     0.722063     0.071203           0.113611
# TCGA-G3-A3CH-11        0.048158     0.854676     0.013161           0.083858
# TCGA-CC-A3MB-01        0.240361     0.464779     0.097803           0.196934
# TCGA-BC-A3KF-01        0.107525     0.691629     0.047043           0.153734
# TCGA-DD-A4NV-01        0.070443     0.654256     0.077110           0.198085
#
#                  Bi-Potent Cells  P-value  Correlation      RMSE
# Mixture
# TCGA-FV-A495-01         0.000414        0     0.934386  0.706663
# TCGA-G3-A3CH-11         0.000148        0     0.841028  0.709516
# TCGA-CC-A3MB-01         0.000123        0     0.847104  0.828112
# TCGA-BC-A3KF-01         0.000070        0     0.888611  0.737731
# TCGA-DD-A4NV-01         0.000106        0     0.893133  0.748995

# %%
sample_list = [sample for sample in estimation.index.values if '-01' in sample]
estimation = estimation.reindex(sample_list)

# %%
survival_data = pd.read_csv('survival_LIHC_survival.txt',index_col=0,delimiter='\t')
sample_list = [sample for sample in survival_data.index.values if '-01' in sample]
survival_data = survival_data.reindex(sample_list)
survival_data.head()
# Out:
#                      _PATIENT  OS  OS.time  DSS  DSS.time  DFI  DFI.time  PFI  \
# sample
# TCGA-2V-A95S-01  TCGA-2V-A95S   0      NaN  0.0       NaN  0.0       NaN    0
# TCGA-2Y-A9GS-01  TCGA-2Y-A9GS   1    724.0  1.0     724.0  1.0     102.0    1
# TCGA-2Y-A9GT-01  TCGA-2Y-A9GT   1   1624.0  1.0    1624.0  1.0    1083.0    1
# TCGA-2Y-A9GU-01  TCGA-2Y-A9GU   0   1939.0  0.0    1939.0  0.0    1939.0    0
# TCGA-2Y-A9GV-01  TCGA-2Y-A9GV   1   2532.0  1.0    2532.0  0.0    2532.0    1
#
#                  PFI.time Redaction
# sample
# TCGA-2V-A95S-01       NaN       NaN
# TCGA-2Y-A9GS-01     102.0       NaN
# TCGA-2Y-A9GT-01    1083.0       NaN
# TCGA-2Y-A9GU-01    1939.0       NaN
# TCGA-2Y-A9GV-01    1745.0       NaN

# %%
dfs_data = survival_data.filter(['DFI.time', 'DFI'])
dfs_data = dfs_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
dfs_data['DFS_E'] = [binary[event] for event in dfs_data['DFI']]
dfs_data['DFS_T'] = [time/30 for time in dfs_data['DFI.time']]
dfs_data.head()
# Out:
#                  DFI.time  DFI  DFS_E      DFS_T
# sample
# TCGA-2Y-A9GS-01     102.0  1.0   True   3.400000
# TCGA-2Y-A9GT-01    1083.0  1.0   True  36.100000
# TCGA-2Y-A9GU-01    1939.0  0.0  False  64.633333
# TCGA-2Y-A9GV-01    2532.0  0.0  False  84.400000
# TCGA-2Y-A9GW-01    1229.0  1.0   True  40.966667

# %%
survival_test = estimation.merge(dfs_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                  Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# TCGA-FV-A495-01        0.092709     0.722063     0.071203           0.113611
# TCGA-CC-A3MB-01        0.240361     0.464779     0.097803           0.196934
# TCGA-BC-A3KF-01        0.107525     0.691629     0.047043           0.153734
# TCGA-DD-A4NV-01        0.070443     0.654256     0.077110           0.198085
# TCGA-BD-A3EP-01        0.219467     0.430477     0.108180           0.240703
#
#                  Bi-Potent Cells  P-value  Correlation      RMSE  DFI.time  \
# TCGA-FV-A495-01         0.000414        0     0.934386  0.706663       1.0
# TCGA-CC-A3MB-01         0.000123        0     0.847104  0.828112     315.0
# TCGA-BC-A3KF-01         0.000070        0     0.888611  0.737731       8.0
# TCGA-DD-A4NV-01         0.000106        0     0.893133  0.748995    2398.0
# TCGA-BD-A3EP-01         0.001173        0     0.677601  0.878487     409.0
#
#                  DFI  DFS_E      DFS_T
# TCGA-FV-A495-01  0.0  False   0.033333
# TCGA-CC-A3MB-01  0.0  False  10.500000
# TCGA-BC-A3KF-01  0.0  False   0.266667
# TCGA-DD-A4NV-01  0.0  False  79.933333
# TCGA-BD-A3EP-01  0.0  False  13.633333

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder.head()
# Out:
#                  Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# TCGA-5R-AA1D-01        0.136538     0.295752     0.136812           0.420384
# TCGA-ED-A82E-01        0.326599     0.000000     0.277936           0.378966
# TCGA-DD-A3A6-01        0.181355     0.000000     0.443425           0.375219
# TCGA-FV-A3R3-01        0.156186     0.366071     0.134264           0.340700
# TCGA-ED-A97K-01        0.338450     0.187866     0.138165           0.332027
#
#                  Bi-Potent Cells  P-value  Correlation      RMSE  DFI.time  \
# TCGA-5R-AA1D-01         0.010514        0     0.538180  0.931786     449.0
# TCGA-ED-A82E-01         0.016499        0     0.402865  0.981271     408.0
# TCGA-DD-A3A6-01         0.000000        0     0.230881  0.991106    3258.0
# TCGA-FV-A3R3-01         0.002779        0     0.608653  0.907029     366.0
# TCGA-ED-A97K-01         0.003492        0     0.702885  0.936831       6.0
#
#                  DFI  DFS_E       DFS_T
# TCGA-5R-AA1D-01  0.0  False   14.966667
# TCGA-ED-A82E-01  0.0  False   13.600000
# TCGA-DD-A3A6-01  0.0  False  108.600000
# TCGA-FV-A3R3-01  0.0  False   12.200000
# TCGA-ED-A97K-01  0.0  False    0.200000

# %%
running_length = len(survival_reorder)

logrank_tests = []
cut_points = []

for i in range(running_length):
    cut_point = int(i+1)
    E = list(survival_reorder['DFS_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['DFS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
optimization
# Out:
# 287

# %%
dfs_cut_level = survival_reorder[selected_cell][optimization]
dfs_cut_level
# Out:
# 0.0876153308062603

# %%
E = list(survival_reorder['DFS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['DFS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 0.02671

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='b')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0.2,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='b',label='High Level of Endothelial Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of Endothelial Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Disease-free Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.DFS.pdf'%selected_cell,format='pdf')

# %%
os_data = survival_data.filter(['OS.time', 'OS'])
os_data = os_data.dropna(axis=0,how='any')
binary = {1:True,0:False}
os_data['OS_E'] = [binary[event] for event in os_data['OS']]
os_data['OS_T'] = [time/30 for time in os_data['OS.time']]
os_data.head()
# Out:
#                  OS.time  OS   OS_E       OS_T
# sample
# TCGA-2Y-A9GS-01    724.0   1   True  24.133333
# TCGA-2Y-A9GT-01   1624.0   1   True  54.133333
# TCGA-2Y-A9GU-01   1939.0   0  False  64.633333
# TCGA-2Y-A9GV-01   2532.0   1   True  84.400000
# TCGA-2Y-A9GW-01   1271.0   1   True  42.366667

# %%
survival_test = estimation.merge(os_data,left_index=True,right_index=True,how='inner')
survival_test.head()
# Out:
#                  Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# TCGA-FV-A495-01        0.092709     0.722063     0.071203           0.113611
# TCGA-CC-A3MB-01        0.240361     0.464779     0.097803           0.196934
# TCGA-BC-A3KF-01        0.107525     0.691629     0.047043           0.153734
# TCGA-DD-A4NV-01        0.070443     0.654256     0.077110           0.198085
# TCGA-CC-A1HT-01        0.452148     0.035019     0.152632           0.355295
#
#                  Bi-Potent Cells  P-value  Correlation      RMSE  OS.time  OS  \
# TCGA-FV-A495-01         0.000414        0     0.934386  0.706663      1.0   0
# TCGA-CC-A3MB-01         0.000123        0     0.847104  0.828112    315.0   1
# TCGA-BC-A3KF-01         0.000070        0     0.888611  0.737731      8.0   0
# TCGA-DD-A4NV-01         0.000106        0     0.893133  0.748995   2398.0   0
# TCGA-CC-A1HT-01         0.004907        0     0.584952  0.978668    101.0   1
#
#                   OS_E       OS_T
# TCGA-FV-A495-01  False   0.033333
# TCGA-CC-A3MB-01   True  10.500000
# TCGA-BC-A3KF-01  False   0.266667
# TCGA-DD-A4NV-01  False  79.933333
# TCGA-CC-A1HT-01   True   3.366667

# %%
survival_reorder = survival_test.sort_values(selected_cell,axis=0,ascending=False)
survival_reorder
# Out:
#                  Immune cluster  Hepatocytes  Fibroblasts  Endothelial Cells  \
# TCGA-5R-AA1D-01        0.136538     0.295752     0.136812           0.420384
# TCGA-MR-A8JO-01        0.217862     0.107002     0.257419           0.407751
# TCGA-ED-A82E-01        0.326599     0.000000     0.277936           0.378966
# TCGA-DD-A3A6-01        0.181355     0.000000     0.443425           0.375219
# TCGA-CC-A1HT-01        0.452148     0.035019     0.152632           0.355295
# ...                         ...          ...          ...                ...
# TCGA-DD-AADO-01        0.132661     0.798305     0.017344           0.051125
# TCGA-G3-A7M5-01        0.038002     0.901635     0.009194           0.051110
# TCGA-BC-A5W4-01        0.122511     0.812020     0.014559           0.050723
# TCGA-2Y-A9H1-01        0.044564     0.893453     0.009965           0.048912
# TCGA-DD-AADS-01        0.008079     0.972718     0.000000           0.019179
#
#                  Bi-Potent Cells  P-value  Correlation      RMSE  OS.time  OS  \
# TCGA-5R-AA1D-01         0.010514        0     0.538180  0.931786    449.0   0
# TCGA-MR-A8JO-01         0.009966        0     0.500543  0.968630    330.0   0
# TCGA-ED-A82E-01         0.016499        0     0.402865  0.981271    408.0   0
# TCGA-DD-A3A6-01         0.000000        0     0.230881  0.991106   3258.0   1
# TCGA-CC-A1HT-01         0.004907        0     0.584952  0.978668    101.0   1
# ...                          ...      ...          ...       ...      ...  ..
# TCGA-DD-AADO-01         0.000564        0     0.830098  0.730760    453.0   0
# TCGA-G3-A7M5-01         0.000060        0     0.894593  0.664733    447.0   0
# TCGA-BC-A5W4-01         0.000188        0     0.864625  0.709450    547.0   1
# TCGA-2Y-A9H1-01         0.003106        0     0.909980  0.658000   1229.0   1
# TCGA-DD-AADS-01         0.000024        0     0.916486  0.627216    474.0   0
#
#                   OS_E        OS_T
# TCGA-5R-AA1D-01  False   14.966667
# TCGA-MR-A8JO-01  False   11.000000
# TCGA-ED-A82E-01  False   13.600000
# TCGA-DD-A3A6-01   True  108.600000
# TCGA-CC-A1HT-01   True    3.366667
# ...                ...         ...
# TCGA-DD-AADO-01  False   15.100000
# TCGA-G3-A7M5-01  False   14.900000
# TCGA-BC-A5W4-01   True   18.233333
# TCGA-2Y-A9H1-01   True   40.966667
# TCGA-DD-AADS-01  False   15.800000
#
# [370 rows x 12 columns]

# %%
running_length = len(survival_reorder)

logrank_tests = []
cut_points = []

for i in range(running_length):
    cut_point = int(i+1)
    E = list(survival_reorder['OS_E'])
    mid_point = int(len(E)/2)
    E_high = E[:cut_point]
    E_low = E[cut_point:]
    S = list(survival_reorder['OS_T'])
    S_high = S[:cut_point]
    S_low = S[cut_point:]
    results = logrank_test(S_high,S_low,E_high,E_low)
    p = results.p_value
    cut_points.append(cut_point)
    logrank_tests.append(p)

optimization = pd.DataFrame(logrank_tests,index=cut_points,columns=['Log Rank Test'])

# %%
optimization = optimization.dropna()
optimization = optimization.sort_values('Log Rank Test')
optimization = int(optimization.iloc[0].name)
optimization
# Out:
# 23

# %%
os_cut_level = survival_reorder[selected_cell][optimization]
os_cut_level
# Out:
# 0.30140309035831897

# %%
E = list(survival_reorder['OS_E'])
cut_point = optimization
E_high = E[:cut_point]
E_low = E[cut_point:]
S = list(survival_reorder['OS_T'])
S_high = S[:cut_point]
S_low = S[cut_point:]
results = logrank_test(S_high,S_low,E_high,E_low)
p = results.p_value
p = round(p,5)
p
# Out:
# 0.00226

# %%
plt.figure(figsize=(6,6))
t,s = kmf(E_high, S_high)
plt.step(t,s,c='b')
t,s = kmf(E_low, S_low)
plt.step(t,s,c='k')
plt.xticks(np.arange(0,121,40),fontsize=12)
plt.yticks(np.arange(0.2,1.1,0.2),fontsize=12)
plt.xlabel('Survival Length (Months)', fontsize=20)
plt.ylabel('Survival Probability',fontsize=20)
high_patch = mpatches.Patch(color='b',label='High Level of Endothelial Cells (n = %s)'%len(E_high))
low_patch = mpatches.Patch(color='k',label='Low Level of Endothelial Cells (n = %s)'%len(E_low))
plt.text(80,0.82, 'Log Rank Test',fontsize=15)
plt.text(83,0.77, 'p = %s'%p,fontsize=15)
plt.legend(handles=[high_patch,low_patch],fontsize=10)
plt.title('Overall Survival (TCGA-LIHC)',fontsize=16)
plt.savefig('TCGA-LIHC.%s.OS.pdf'%selected_cell,format='pdf')

# %%
estimation = estimation.sort_values(selected_cell,ascending=False)
x = []
y = []
for key,value in enumerate(estimation[selected_cell]):
    x.append(key)
    y.append(value)

# %%
plt.figure(figsize=(6,6))
plt.scatter(x,y,color='orange')
plt.axhline(y=os_cut_level, xmin=0, xmax=100,color='k')
plt.axhline(y=dfs_cut_level, xmin=0, xmax=100,color='b')
plt.ylabel('Estimated Cell Fraction',fontsize=15)
plt.title('Cutting Point - Endothelial Cells',fontsize=15)
dfs_patch = mpatches.Patch(color='b',label='DFS Cutting Level')
os_patch = mpatches.Patch(color='k',label='OS Cutting Level')
plt.legend(handles=[dfs_patch,os_patch],fontsize=12)
plt.savefig('Cutting_Point.%s'%selected_cell,format='pdf')
