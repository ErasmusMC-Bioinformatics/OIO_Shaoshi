# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os

# %%
selected_cell = 'Bi-Potent Cells'

# %%
box_data = {}
position = {}
widths = {}
box_properties = {}

# %%
study = 'LIRI-JP'
svr_estimation = pd.read_csv('%s.RNA-Seq/%s.%s.csv'%(selected_cell.replace(' ','.'),study,selected_cell),index_col=0)
metadata = pd.read_csv('Phenotype/%s.csv'%study)
primary = metadata[metadata['Phenotype'] == 'Primary']
primary_list = list(primary['submitted_sample_id'])
primary = svr_estimation.reindex(primary_list)
primary = np.array(primary[selected_cell])

nt = metadata[metadata['Phenotype'] == 'Non-Tumor']
nt_list = list(nt['submitted_sample_id'])
nt = svr_estimation.reindex(nt_list)
nt = np.array(nt[selected_cell])

secondary = metadata[metadata['Phenotype'] == 'Secondary']
secondary_list = list(secondary['submitted_sample_id'])
secondary = svr_estimation.reindex(secondary_list)
secondary = np.array(secondary[selected_cell])

box_no = 1
box_data[box_no] = primary
position[box_no] = [7]
widths[box_no] = 2.5
box_properties[box_no] = 'primary'

box_no = 2
box_data[box_no] = nt
position[box_no] = [10]
widths[box_no] = 2.5
box_properties[box_no] = 'nt'

box_no = 3
box_data[box_no] = secondary
position[box_no] = [13]
widths[box_no] = 2.5
box_properties[box_no] = 'secondary'

# %%
study = 'GSE119336'
svr_estimation = pd.read_csv('%s.RNA-Seq/%s.%s.csv'%(selected_cell.replace(' ','.'),study,selected_cell),index_col=0)
metadata = pd.read_csv('Phenotype/%s.csv'%study)
nt = metadata[metadata['Phenotype'] == 'Non-Tumor']
nt_list = list(nt['title'])
nt = svr_estimation.reindex(nt_list)
nt = np.array(nt[selected_cell])
cancer = metadata[metadata['Phenotype'] == 'CCA']
cancer_list = list(cancer['title'])
cancer = svr_estimation.reindex(cancer_list)
cancer = np.array(cancer[selected_cell])

box_no = 4
box_data[box_no] = nt
position[box_no] = [18]
widths[box_no] = 3
box_properties[box_no] = 'nt'

box_no = 5
box_data[box_no] = cancer
position[box_no] = [22]
widths[box_no] = 3
box_properties[box_no] = 'cca'

# %%
study = 'GSE124535'
svr_estimation = pd.read_csv('%s.RNA-Seq/%s.%s.csv'%(selected_cell.replace(' ','.'),study,selected_cell),index_col=0)
metadata = pd.read_csv('Phenotype/%s.csv'%study)
metadata.index = metadata['geo_accession']
nt = metadata[metadata['Phenotype'] == 'Non-Tumor']
nt_list = list(nt.index.values)
nt = svr_estimation.reindex(nt_list)
nt = np.array(nt[selected_cell])
cancer = metadata[metadata['Phenotype'] == 'HCC']
cancer_list = list(cancer.index.values)
cancer = svr_estimation.reindex(cancer_list)
cancer = np.array(cancer[selected_cell])

box_no = 6
box_data[box_no] = nt
position[box_no] = [28]
widths[box_no] = 3
box_properties[box_no] = 'nt'

box_no = 7
box_data[box_no] = cancer
position[box_no] = [32]
widths[box_no] = 3
box_properties[box_no] = 'hcc'

# %%
study = 'GSE65485'
svr_estimation = pd.read_csv('%s.RNA-Seq/%s.%s.csv'%(selected_cell.replace(' ','.'),study,selected_cell),index_col=0)
metadata = pd.read_csv('Phenotype/%s.csv'%study)
metadata.index = metadata['sample_id']
nt = metadata[metadata['Phenotype'] == 'Non-Tumor']
nt_list = list(nt.index.values)
nt = svr_estimation.reindex(nt_list)
nt = np.array(nt[selected_cell])
cancer = metadata[metadata['Phenotype'] == 'HCC']
cancer_list = list(cancer.index.values)
cancer = svr_estimation.reindex(cancer_list)
cancer = np.array(cancer[selected_cell])

box_no = 8
box_data[box_no] = nt
position[box_no] = [38]
widths[box_no] = 3
box_properties[box_no] = 'nt'

box_no = 9
box_data[box_no] = cancer
position[box_no] = [42]
widths[box_no] = 3
box_properties[box_no] = 'hcc'

# %%
study = 'GSE77314'
svr_estimation = pd.read_csv('%s.RNA-Seq/%s.%s.csv'%(selected_cell.replace(' ','.'),study,selected_cell),index_col=0)
metadata = pd.read_csv('Phenotype/%s.csv'%study)
metadata.index = metadata['sample_id']
nt = metadata[metadata['Phenotype'] == 'Non-Tumor']
nt_list = list(nt.index.values)
nt = svr_estimation.reindex(nt_list)
nt = np.array(nt[selected_cell])
cancer = metadata[metadata['Phenotype'] == 'HCC']
cancer_list = list(cancer.index.values)
cancer = svr_estimation.reindex(cancer_list)
cancer = np.array(cancer[selected_cell])

box_no = 10
box_data[box_no] = nt
position[box_no] = [48]
widths[box_no] = 3
box_properties[box_no] = 'nt'

box_no = 11
box_data[box_no] = cancer
position[box_no] = [52]
widths[box_no] = 3
box_properties[box_no] = 'hcc'

# %%
study = 'GSE77509'
svr_estimation = pd.read_csv('%s.RNA-Seq/%s.%s.csv'%(selected_cell.replace(' ','.'),study,selected_cell),index_col=0)
metadata = pd.read_csv('Phenotype/%s.csv'%study)
metadata.index = metadata['geo_accession']
nt = metadata[metadata['Phenotype'] == 'Non-Tumor']
nt_list = list(nt.index.values)
nt = svr_estimation.reindex(nt_list)
nt = np.array(nt[selected_cell])
cancer = metadata[metadata['Phenotype'] == 'HCC']
cancer_list = list(cancer.index.values)
cancer = svr_estimation.reindex(cancer_list)
cancer = np.array(cancer[selected_cell])
pvtt = metadata[metadata['Phenotype'] == 'HCC-PVTT']
pvtt_list = list(pvtt.index.values)
pvtt = svr_estimation.reindex(pvtt_list)
pvtt = np.array(pvtt[selected_cell])

box_no = 12
box_data[box_no] = nt
position[box_no] = [57]
widths[box_no] = 2.5
box_properties[box_no] = 'nt'


box_no = 13
box_data[box_no] = cancer
position[box_no] = [60]
widths[box_no] = 2.5
box_properties[box_no] = 'hcc'

box_no = 14
box_data[box_no] = cancer
position[box_no] = [63]
widths[box_no] = 2.5
box_properties[box_no] = 'pvtt'

# %%
study = 'GSE94660'
svr_estimation = pd.read_csv('%s.RNA-Seq/%s.%s.csv'%(selected_cell.replace(' ','.'),study,selected_cell),index_col=0)
metadata = pd.read_csv('Phenotype/%s.csv'%study)
metadata.index = metadata['geo_accession']
nt = metadata[metadata['Phenotype'] == 'Non-Tumor']
nt_list = list(nt.index.values)
nt = svr_estimation.reindex(nt_list)
nt = np.array(nt[selected_cell])
cancer = metadata[metadata['Phenotype'] == 'HCC']
cancer_list = list(cancer.index.values)
cancer = svr_estimation.reindex(cancer_list)
cancer = np.array(cancer[selected_cell])

box_no = 15
box_data[box_no] = nt
position[box_no] = [68]
widths[box_no] = 3
box_properties[box_no] = 'nt'

box_no = 16
box_data[box_no] = cancer
position[box_no] = [72]
widths[box_no] = 3
box_properties[box_no] = 'hcc'

# %%
box_property = {}
primary_color = '#ff3300'
secondary_color = '#00ccff'
nt_color = '#00ffbf'
cca_color = '#e600e6'
hcc_color = '#ff0066'
pvtt_color = '#0000e6'

box_property['primary'] = dict(linestyle = '-', linewidth = 1, facecolor = primary_color)
box_property['secondary'] = dict(linestyle = '-', linewidth = 1, facecolor = secondary_color)
box_property['nt'] = dict(linestyle = '-', linewidth = 1, facecolor = nt_color)
box_property['cca'] = dict(linestyle = '-', linewidth = 1, facecolor = cca_color)
box_property['hcc'] = dict(linestyle = '-', linewidth = 1, facecolor = hcc_color)
box_property['pvtt'] = dict(linestyle = '-', linewidth = 1, facecolor = pvtt_color)

# %%
plt.figure(figsize=(6,10))

plt.xlim(3,27)
meanlineprops = dict(linestyle='-', linewidth = 1, color = 'blue')

for i in range(5):
    group = i+1
    bp = plt.boxplot(box_data[group], positions=position[group], widths = widths[group], whis=[0,100],
                boxprops = box_property[box_properties[group]],medianprops = meanlineprops, meanline = False, patch_artist=True)


for i in range(5):
    group = i+1
    plt.text(position[group][0]-1,max(box_data[group])+0.01,'n=%s'%(len(box_data[group])),rotation=40)

primary_patch = mpatches.Patch(color=primary_color,label='Primary Liver Cancer')
secondary_patch = mpatches.Patch(color=secondary_color,label='Secondary Liver Cancer')
nt_patch = mpatches.Patch(color=nt_color,label='Non-Tumor Liver')
hcc_patch = mpatches.Patch(color=hcc_color,label='Heptocellular Carcinoma (HCC)')
cca_patch = mpatches.Patch(color=cca_color,label='Cholagiocarcinoma (CCA)')
pvtt_patch = mpatches.Patch(color=pvtt_color,label='Portal Vein Tumor Thrombosis (HCC-PVTT)')

plt.legend(handles=[primary_patch,secondary_patch,nt_patch,cca_patch],
           fontsize=10,loc='upper right')
plt.ylabel('Predicted Proportion',fontsize=15)

plt.title('%s (RNA-Seq)'%(selected_cell), fontsize=20)
plt.yticks([0.29,0.85])
plt.xticks([10,20], ['LIRI-JP','GSE119336'], fontsize=12,rotation=30)
plt.tight_layout()
plt.savefig('RNA-Seq.%s.A.pdf'%selected_cell,format='pdf')

# %%
plt.figure(figsize=(8,10))

plt.xlim(23,77)
meanlineprops = dict(linestyle='-', linewidth = 1, color = 'blue')

for i in range(5,16):
    group = i+1
    bp = plt.boxplot(box_data[group], positions=position[group], widths = widths[group], whis=[0,100],
                boxprops = box_property[box_properties[group]],medianprops = meanlineprops, meanline = False, patch_artist=True)


for i in range(5,16):
    group = i+1
    plt.text(position[group][0]-1.2,max(box_data[group])+0.0005,'n=%s'%(len(box_data[group])),rotation=40)

primary_patch = mpatches.Patch(color=primary_color,label='Primary Liver Cancer')
secondary_patch = mpatches.Patch(color=secondary_color,label='Secondary Liver Cancer')
nt_patch = mpatches.Patch(color=nt_color,label='Non-Tumor Liver')
hcc_patch = mpatches.Patch(color=hcc_color,label='Heptocellular Carcinoma (HCC)')
cca_patch = mpatches.Patch(color=cca_color,label='Cholagiocarcinoma (CCA)')
pvtt_patch = mpatches.Patch(color=pvtt_color,label='Portal Vein Tumor Thrombosis (HCC-PVTT)')

plt.legend(handles=[nt_patch,hcc_patch,pvtt_patch,cca_patch],
           fontsize=10,loc='upper right')
plt.ylabel('Predicted Proportion',fontsize=15)

plt.title('%s (RNA-Seq)'%(selected_cell), fontsize=20)
plt.yticks([0.347,0.385])
plt.xticks([30,40,50,60,70],
           ['GSE124535','GSE65485','GSE77314','GSE77509','GSE94660'],
          fontsize=12,rotation=30)
plt.tight_layout()
plt.savefig('RNA-Seq.%s.B.pdf'%selected_cell,format='pdf')
